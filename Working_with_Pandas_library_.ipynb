# %% [markdown]
# #Pandas
#
# The Pandas library is a Python package used for data manipulation and analysis. Pandas offers powerful tools for data cleaning, transformation, and analysis, making it easier to handle and analyze large datasets.Its capabilities include handling missing data,performing statistical operations making it a popular choice for data scientists and analysts.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd #Importing the pandas library for data manipulation and analysis
df=pd.read_csv('pokemon_data.csv')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
df.shape
# Out:
# (800, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
pd.set_option('display.max_columns',12)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# 791       80    123           6      False
# 792       98     99           6       True
# 793       98     99           6       True
# 794       95     95           6       True
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
#Reading data from a text file which is tab separated
df = pd.read_csv('pokemon_data.txt', delimiter='\t')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Reading Data in Pandas
#printing the column headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#printing specific column
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
#printing specific column until a range
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
#Reading Multiple Columns
print(df[['Name','Type 1','HP']])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
#Reading Rows
#Printing data of a specific row using iloc->integer location
print(df.iloc[1])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
#Reading Rows
#Printing data of a specific range in rows using iloc->integer location
print(df.iloc[1:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
## Read a specific location (R,C)
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
#Using for in to iterate through the rows
for index, row in df.iterrows():
 print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# 67 Poliwrath
# 68 Abra
# 69 Kadabra
# 70 Alakazam
# 71 AlakazamMega Alakazam
# 72 Machop
# 73 Machoke
# 74 Machamp
# 75 Bellsprout
# 76 Weepinbell
# 77 Victreebel
# 78 Tentacool
# 79 Tentacruel
# 80 Geodude
# 81 Graveler
# 82 Golem
# 83 Ponyta
# 84 Rapidash
# 85 Slowpoke
# 86 Slowbro
# 87 SlowbroMega Slowbro
# 88 Magnemite
# 89 Magneton
# 90 Farfetch'd
# 91 Doduo
# 92 Dodrio
# 93 Seel
# 94 Dewgong
# 95 Grimer
# 96 Muk
# 97 Shellder
# 98 Cloyster
# 99 Gastly
# 100 Haunter
# 101 Gengar
# 102 GengarMega Gengar
# 103 Onix
# 104 Drowzee
# 105 Hypno
# 106 Krabby
# 107 Kingler
# 108 Voltorb
# 109 Electrode
# 110 Exeggcute
# 111 Exeggutor
# 112 Cubone
# 113 Marowak
# 114 Hitmonlee
# 115 Hitmonchan
# 116 Lickitung
# 117 Koffing
# 118 Weezing
# 119 Rhyhorn
# 120 Rhydon
# 121 Chansey
# 122 Tangela
# 123 Kangaskhan
# 124 KangaskhanMega Kangaskhan
# 125 Horsea
# 126 Seadra
# 127 Goldeen
# 128 Seaking
# 129 Staryu
# 130 Starmie
# 131 Mr. Mime
# 132 Scyther
# 133 Jynx
# 134 Electabuzz
# 135 Magmar
# 136 Pinsir
# 137 PinsirMega Pinsir
# 138 Tauros
# 139 Magikarp
# 140 Gyarados
# 141 GyaradosMega Gyarados
# 142 Lapras
# 143 Ditto
# 144 Eevee
# 145 Vaporeon
# 146 Jolteon
# 147 Flareon
# 148 Porygon
# 149 Omanyte
# 150 Omastar
# 151 Kabuto
# 152 Kabutops
# 153 Aerodactyl
# 154 AerodactylMega Aerodactyl
# 155 Snorlax
# 156 Articuno
# 157 Zapdos
# 158 Moltres
# 159 Dratini
# 160 Dragonair
# 161 Dragonite
# 162 Mewtwo
# 163 MewtwoMega Mewtwo X
# 164 MewtwoMega Mewtwo Y
# 165 Mew
# 166 Chikorita
# 167 Bayleef
# 168 Meganium
# 169 Cyndaquil
# 170 Quilava
# 171 Typhlosion
# 172 Totodile
# 173 Croconaw
# 174 Feraligatr
# 175 Sentret
# 176 Furret
# 177 Hoothoot
# 178 Noctowl
# 179 Ledyba
# 180 Ledian
# 181 Spinarak
# 182 Ariados
# 183 Crobat
# 184 Chinchou
# 185 Lanturn
# 186 Pichu
# 187 Cleffa
# 188 Igglybuff
# 189 Togepi
# 190 Togetic
# 191 Natu
# 192 Xatu
# 193 Mareep
# 194 Flaaffy
# 195 Ampharos
# 196 AmpharosMega Ampharos
# 197 Bellossom
# 198 Marill
# 199 Azumarill
# 200 Sudowoodo
# 201 Politoed
# 202 Hoppip
# 203 Skiploom
# 204 Jumpluff
# 205 Aipom
# 206 Sunkern
# 207 Sunflora
# 208 Yanma
# 209 Wooper
# 210 Quagsire
# 211 Espeon
# 212 Umbreon
# 213 Murkrow
# 214 Slowking
# 215 Misdreavus
# 216 Unown
# 217 Wobbuffet
# 218 Girafarig
# 219 Pineco
# 220 Forretress
# 221 Dunsparce
# 222 Gligar
# 223 Steelix
# 224 SteelixMega Steelix
# 225 Snubbull
# 226 Granbull
# 227 Qwilfish
# 228 Scizor
# 229 ScizorMega Scizor
# 230 Shuckle
# 231 Heracross
# 232 HeracrossMega Heracross
# 233 Sneasel
# 234 Teddiursa
# 235 Ursaring
# 236 Slugma
# 237 Magcargo
# 238 Swinub
# 239 Piloswine
# 240 Corsola
# 241 Remoraid
# 242 Octillery
# 243 Delibird
# 244 Mantine
# 245 Skarmory
# 246 Houndour
# 247 Houndoom
# 248 HoundoomMega Houndoom
# 249 Kingdra
# 250 Phanpy
# 251 Donphan
# 252 Porygon2
# 253 Stantler
# 254 Smeargle
# 255 Tyrogue
# 256 Hitmontop
# 257 Smoochum
# 258 Elekid
# 259 Magby
# 260 Miltank
# 261 Blissey
# 262 Raikou
# 263 Entei
# 264 Suicune
# 265 Larvitar
# 266 Pupitar
# 267 Tyranitar
# 268 TyranitarMega Tyranitar
# 269 Lugia
# 270 Ho-oh
# 271 Celebi
# 272 Treecko
# 273 Grovyle
# 274 Sceptile
# 275 SceptileMega Sceptile
# 276 Torchic
# 277 Combusken
# 278 Blaziken
# 279 BlazikenMega Blaziken
# 280 Mudkip
# 281 Marshtomp
# 282 Swampert
# 283 SwampertMega Swampert
# 284 Poochyena
# 285 Mightyena
# 286 Zigzagoon
# 287 Linoone
# 288 Wurmple
# 289 Silcoon
# 290 Beautifly
# 291 Cascoon
# 292 Dustox
# 293 Lotad
# 294 Lombre
# 295 Ludicolo
# 296 Seedot
# 297 Nuzleaf
# 298 Shiftry
# 299 Taillow
# 300 Swellow
# 301 Wingull
# 302 Pelipper
# 303 Ralts
# 304 Kirlia
# 305 Gardevoir
# 306 GardevoirMega Gardevoir
# 307 Surskit
# 308 Masquerain
# 309 Shroomish
# 310 Breloom
# 311 Slakoth
# 312 Vigoroth
# 313 Slaking
# 314 Nincada
# 315 Ninjask
# 316 Shedinja
# 317 Whismur
# 318 Loudred
# 319 Exploud
# 320 Makuhita
# 321 Hariyama
# 322 Azurill
# 323 Nosepass
# 324 Skitty
# 325 Delcatty
# 326 Sableye
# 327 SableyeMega Sableye
# 328 Mawile
# 329 MawileMega Mawile
# 330 Aron
# 331 Lairon
# 332 Aggron
# 333 AggronMega Aggron
# 334 Meditite
# 335 Medicham
# 336 MedichamMega Medicham
# 337 Electrike
# 338 Manectric
# 339 ManectricMega Manectric
# 340 Plusle
# 341 Minun
# 342 Volbeat
# 343 Illumise
# 344 Roselia
# 345 Gulpin
# 346 Swalot
# 347 Carvanha
# 348 Sharpedo
# 349 SharpedoMega Sharpedo
# 350 Wailmer
# 351 Wailord
# 352 Numel
# 353 Camerupt
# 354 CameruptMega Camerupt
# 355 Torkoal
# 356 Spoink
# 357 Grumpig
# 358 Spinda
# 359 Trapinch
# 360 Vibrava
# 361 Flygon
# 362 Cacnea
# 363 Cacturne
# 364 Swablu
# 365 Altaria
# 366 AltariaMega Altaria
# 367 Zangoose
# 368 Seviper
# 369 Lunatone
# 370 Solrock
# 371 Barboach
# 372 Whiscash
# 373 Corphish
# 374 Crawdaunt
# 375 Baltoy
# 376 Claydol
# 377 Lileep
# 378 Cradily
# 379 Anorith
# 380 Armaldo
# 381 Feebas
# 382 Milotic
# 383 Castform
# 384 Kecleon
# 385 Shuppet
# 386 Banette
# 387 BanetteMega Banette
# 388 Duskull
# 389 Dusclops
# 390 Tropius
# 391 Chimecho
# 392 Absol
# 393 AbsolMega Absol
# 394 Wynaut
# 395 Snorunt
# 396 Glalie
# 397 GlalieMega Glalie
# 398 Spheal
# 399 Sealeo
# 400 Walrein
# 401 Clamperl
# 402 Huntail
# 403 Gorebyss
# 404 Relicanth
# 405 Luvdisc
# 406 Bagon
# 407 Shelgon
# 408 Salamence
# 409 SalamenceMega Salamence
# 410 Beldum
# 411 Metang
# 412 Metagross
# 413 MetagrossMega Metagross
# 414 Regirock
# 415 Regice
# 416 Registeel
# 417 Latias
# 418 LatiasMega Latias
# 419 Latios
# 420 LatiosMega Latios
# 421 Kyogre
# 422 KyogrePrimal Kyogre
# 423 Groudon
# 424 GroudonPrimal Groudon
# 425 Rayquaza
# 426 RayquazaMega Rayquaza
# 427 Jirachi
# 428 DeoxysNormal Forme
# 429 DeoxysAttack Forme
# 430 DeoxysDefense Forme
# 431 DeoxysSpeed Forme
# 432 Turtwig
# 433 Grotle
# 434 Torterra
# 435 Chimchar
# 436 Monferno
# 437 Infernape
# 438 Piplup
# 439 Prinplup
# 440 Empoleon
# 441 Starly
# 442 Staravia
# 443 Staraptor
# 444 Bidoof
# 445 Bibarel
# 446 Kricketot
# 447 Kricketune
# 448 Shinx
# 449 Luxio
# 450 Luxray
# 451 Budew
# 452 Roserade
# 453 Cranidos
# 454 Rampardos
# 455 Shieldon
# 456 Bastiodon
# 457 Burmy
# 458 WormadamPlant Cloak
# 459 WormadamSandy Cloak
# 460 WormadamTrash Cloak
# 461 Mothim
# 462 Combee
# 463 Vespiquen
# 464 Pachirisu
# 465 Buizel
# 466 Floatzel
# 467 Cherubi
# 468 Cherrim
# 469 Shellos
# 470 Gastrodon
# 471 Ambipom
# 472 Drifloon
# 473 Drifblim
# 474 Buneary
# 475 Lopunny
# 476 LopunnyMega Lopunny
# 477 Mismagius
# 478 Honchkrow
# 479 Glameow
# 480 Purugly
# 481 Chingling
# 482 Stunky
# 483 Skuntank
# 484 Bronzor
# 485 Bronzong
# 486 Bonsly
# 487 Mime Jr.
# 488 Happiny
# 489 Chatot
# 490 Spiritomb
# 491 Gible
# 492 Gabite
# 493 Garchomp
# 494 GarchompMega Garchomp
# 495 Munchlax
# 496 Riolu
# 497 Lucario
# 498 LucarioMega Lucario
# 499 Hippopotas
# 500 Hippowdon
# 501 Skorupi
# 502 Drapion
# 503 Croagunk
# 504 Toxicroak
# 505 Carnivine
# 506 Finneon
# 507 Lumineon
# 508 Mantyke
# 509 Snover
# 510 Abomasnow
# 511 AbomasnowMega Abomasnow
# 512 Weavile
# 513 Magnezone
# 514 Lickilicky
# 515 Rhyperior
# 516 Tangrowth
# 517 Electivire
# 518 Magmortar
# 519 Togekiss
# 520 Yanmega
# 521 Leafeon
# 522 Glaceon
# 523 Gliscor
# 524 Mamoswine
# 525 Porygon-Z
# 526 Gallade
# 527 GalladeMega Gallade
# 528 Probopass
# 529 Dusknoir
# 530 Froslass
# 531 Rotom
# 532 RotomHeat Rotom
# 533 RotomWash Rotom
# 534 RotomFrost Rotom
# 535 RotomFan Rotom
# 536 RotomMow Rotom
# 537 Uxie
# 538 Mesprit
# 539 Azelf
# 540 Dialga
# 541 Palkia
# 542 Heatran
# 543 Regigigas
# 544 GiratinaAltered Forme
# 545 GiratinaOrigin Forme
# 546 Cresselia
# 547 Phione
# 548 Manaphy
# 549 Darkrai
# 550 ShayminLand Forme
# 551 ShayminSky Forme
# 552 Arceus
# 553 Victini
# 554 Snivy
# 555 Servine
# 556 Serperior
# 557 Tepig
# 558 Pignite
# 559 Emboar
# 560 Oshawott
# 561 Dewott
# 562 Samurott
# 563 Patrat
# 564 Watchog
# 565 Lillipup
# 566 Herdier
# 567 Stoutland
# 568 Purrloin
# 569 Liepard
# 570 Pansage
# 571 Simisage
# 572 Pansear
# 573 Simisear
# 574 Panpour
# 575 Simipour
# 576 Munna
# 577 Musharna
# 578 Pidove
# 579 Tranquill
# 580 Unfezant
# 581 Blitzle
# 582 Zebstrika
# 583 Roggenrola
# 584 Boldore
# 585 Gigalith
# 586 Woobat
# 587 Swoobat
# 588 Drilbur
# 589 Excadrill
# 590 Audino
# 591 AudinoMega Audino
# 592 Timburr
# 593 Gurdurr
# 594 Conkeldurr
# 595 Tympole
# 596 Palpitoad
# 597 Seismitoad
# 598 Throh
# 599 Sawk
# 600 Sewaddle
# 601 Swadloon
# 602 Leavanny
# 603 Venipede
# 604 Whirlipede
# 605 Scolipede
# 606 Cottonee
# 607 Whimsicott
# 608 Petilil
# 609 Lilligant
# 610 Basculin
# 611 Sandile
# 612 Krokorok
# 613 Krookodile
# 614 Darumaka
# 615 DarmanitanStandard Mode
# 616 DarmanitanZen Mode
# 617 Maractus
# 618 Dwebble
# 619 Crustle
# 620 Scraggy
# 621 Scrafty
# 622 Sigilyph
# 623 Yamask
# 624 Cofagrigus
# 625 Tirtouga
# 626 Carracosta
# 627 Archen
# 628 Archeops
# 629 Trubbish
# 630 Garbodor
# 631 Zorua
# 632 Zoroark
# 633 Minccino
# 634 Cinccino
# 635 Gothita
# 636 Gothorita
# 637 Gothitelle
# 638 Solosis
# 639 Duosion
# 640 Reuniclus
# 641 Ducklett
# 642 Swanna
# 643 Vanillite
# 644 Vanillish
# 645 Vanilluxe
# 646 Deerling
# 647 Sawsbuck
# 648 Emolga
# 649 Karrablast
# 650 Escavalier
# 651 Foongus
# 652 Amoonguss
# 653 Frillish
# 654 Jellicent
# 655 Alomomola
# 656 Joltik
# 657 Galvantula
# 658 Ferroseed
# 659 Ferrothorn
# 660 Klink
# 661 Klang
# 662 Klinklang
# 663 Tynamo
# 664 Eelektrik
# 665 Eelektross
# 666 Elgyem
# 667 Beheeyem
# 668 Litwick
# 669 Lampent
# 670 Chandelure
# 671 Axew
# 672 Fraxure
# 673 Haxorus
# 674 Cubchoo
# 675 Beartic
# 676 Cryogonal
# 677 Shelmet
# 678 Accelgor
# 679 Stunfisk
# 680 Mienfoo
# 681 Mienshao
# 682 Druddigon
# 683 Golett
# 684 Golurk
# 685 Pawniard
# 686 Bisharp
# 687 Bouffalant
# 688 Rufflet
# 689 Braviary
# 690 Vullaby
# 691 Mandibuzz
# 692 Heatmor
# 693 Durant
# 694 Deino
# 695 Zweilous
# 696 Hydreigon
# 697 Larvesta
# 698 Volcarona
# 699 Cobalion
# 700 Terrakion
# 701 Virizion
# 702 TornadusIncarnate Forme
# 703 TornadusTherian Forme
# 704 ThundurusIncarnate Forme
# 705 ThundurusTherian Forme
# 706 Reshiram
# 707 Zekrom
# 708 LandorusIncarnate Forme
# 709 LandorusTherian Forme
# 710 Kyurem
# 711 KyuremBlack Kyurem
# 712 KyuremWhite Kyurem
# 713 KeldeoOrdinary Forme
# 714 KeldeoResolute Forme
# 715 MeloettaAria Forme
# 716 MeloettaPirouette Forme
# 717 Genesect
# 718 Chespin
# 719 Quilladin
# 720 Chesnaught
# 721 Fennekin
# 722 Braixen
# 723 Delphox
# 724 Froakie
# 725 Frogadier
# 726 Greninja
# 727 Bunnelby
# 728 Diggersby
# 729 Fletchling
# 730 Fletchinder
# 731 Talonflame
# 732 Scatterbug
# 733 Spewpa
# 734 Vivillon
# 735 Litleo
# 736 Pyroar
# 737 Flabébé
# 738 Floette
# 739 Florges
# 740 Skiddo
# 741 Gogoat
# 742 Pancham
# 743 Pangoro
# 744 Furfrou
# 745 Espurr
# 746 MeowsticMale
# 747 MeowsticFemale
# 748 Honedge
# 749 Doublade
# 750 AegislashBlade Forme
# 751 AegislashShield Forme
# 752 Spritzee
# 753 Aromatisse
# 754 Swirlix
# 755 Slurpuff
# 756 Inkay
# 757 Malamar
# 758 Binacle
# 759 Barbaracle
# 760 Skrelp
# 761 Dragalge
# 762 Clauncher
# 763 Clawitzer
# 764 Helioptile
# 765 Heliolisk
# 766 Tyrunt
# 767 Tyrantrum
# 768 Amaura
# 769 Aurorus
# 770 Sylveon
# 771 Hawlucha
# 772 Dedenne
# 773 Carbink
# 774 Goomy
# 775 Sliggoo
# 776 Goodra
# 777 Klefki
# 778 Phantump
# 779 Trevenant
# 780 PumpkabooAverage Size
# 781 PumpkabooSmall Size
# 782 PumpkabooLarge Size
# 783 PumpkabooSuper Size
# 784 GourgeistAverage Size
# 785 GourgeistSmall Size
# 786 GourgeistLarge Size
# 787 GourgeistSuper Size
# 788 Bergmite
# 789 Avalugg
# 790 Noibat
# 791 Noivern
# 792 Xerneas
# 793 Yveltal
# 794 Zygarde50% Forme
# 795 Diancie
# 796 DiancieMega Diancie
# 797 HoopaHoopa Confined
# 798 HoopaHoopa Unbound
# 799 Volcanion

# %%
#Using for in to iterate through the rows
for index, row in df.iterrows():
 print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# 67 Poliwrath
# 68 Abra
# 69 Kadabra
# 70 Alakazam
# 71 AlakazamMega Alakazam
# 72 Machop
# 73 Machoke
# 74 Machamp
# 75 Bellsprout
# 76 Weepinbell
# 77 Victreebel
# 78 Tentacool
# 79 Tentacruel
# 80 Geodude
# 81 Graveler
# 82 Golem
# 83 Ponyta
# 84 Rapidash
# 85 Slowpoke
# 86 Slowbro
# 87 SlowbroMega Slowbro
# 88 Magnemite
# 89 Magneton
# 90 Farfetch'd
# 91 Doduo
# 92 Dodrio
# 93 Seel
# 94 Dewgong
# 95 Grimer
# 96 Muk
# 97 Shellder
# 98 Cloyster
# 99 Gastly
# 100 Haunter
# 101 Gengar
# 102 GengarMega Gengar
# 103 Onix
# 104 Drowzee
# 105 Hypno
# 106 Krabby
# 107 Kingler
# 108 Voltorb
# 109 Electrode
# 110 Exeggcute
# 111 Exeggutor
# 112 Cubone
# 113 Marowak
# 114 Hitmonlee
# 115 Hitmonchan
# 116 Lickitung
# 117 Koffing
# 118 Weezing
# 119 Rhyhorn
# 120 Rhydon
# 121 Chansey
# 122 Tangela
# 123 Kangaskhan
# 124 KangaskhanMega Kangaskhan
# 125 Horsea
# 126 Seadra
# 127 Goldeen
# 128 Seaking
# 129 Staryu
# 130 Starmie
# 131 Mr. Mime
# 132 Scyther
# 133 Jynx
# 134 Electabuzz
# 135 Magmar
# 136 Pinsir
# 137 PinsirMega Pinsir
# 138 Tauros
# 139 Magikarp
# 140 Gyarados
# 141 GyaradosMega Gyarados
# 142 Lapras
# 143 Ditto
# 144 Eevee
# 145 Vaporeon
# 146 Jolteon
# 147 Flareon
# 148 Porygon
# 149 Omanyte
# 150 Omastar
# 151 Kabuto
# 152 Kabutops
# 153 Aerodactyl
# 154 AerodactylMega Aerodactyl
# 155 Snorlax
# 156 Articuno
# 157 Zapdos
# 158 Moltres
# 159 Dratini
# 160 Dragonair
# 161 Dragonite
# 162 Mewtwo
# 163 MewtwoMega Mewtwo X
# 164 MewtwoMega Mewtwo Y
# 165 Mew
# 166 Chikorita
# 167 Bayleef
# 168 Meganium
# 169 Cyndaquil
# 170 Quilava
# 171 Typhlosion
# 172 Totodile
# 173 Croconaw
# 174 Feraligatr
# 175 Sentret
# 176 Furret
# 177 Hoothoot
# 178 Noctowl
# 179 Ledyba
# 180 Ledian
# 181 Spinarak
# 182 Ariados
# 183 Crobat
# 184 Chinchou
# 185 Lanturn
# 186 Pichu
# 187 Cleffa
# 188 Igglybuff
# 189 Togepi
# 190 Togetic
# 191 Natu
# 192 Xatu
# 193 Mareep
# 194 Flaaffy
# 195 Ampharos
# 196 AmpharosMega Ampharos
# 197 Bellossom
# 198 Marill
# 199 Azumarill
# 200 Sudowoodo
# 201 Politoed
# 202 Hoppip
# 203 Skiploom
# 204 Jumpluff
# 205 Aipom
# 206 Sunkern
# 207 Sunflora
# 208 Yanma
# 209 Wooper
# 210 Quagsire
# 211 Espeon
# 212 Umbreon
# 213 Murkrow
# 214 Slowking
# 215 Misdreavus
# 216 Unown
# 217 Wobbuffet
# 218 Girafarig
# 219 Pineco
# 220 Forretress
# 221 Dunsparce
# 222 Gligar
# 223 Steelix
# 224 SteelixMega Steelix
# 225 Snubbull
# 226 Granbull
# 227 Qwilfish
# 228 Scizor
# 229 ScizorMega Scizor
# 230 Shuckle
# 231 Heracross
# 232 HeracrossMega Heracross
# 233 Sneasel
# 234 Teddiursa
# 235 Ursaring
# 236 Slugma
# 237 Magcargo
# 238 Swinub
# 239 Piloswine
# 240 Corsola
# 241 Remoraid
# 242 Octillery
# 243 Delibird
# 244 Mantine
# 245 Skarmory
# 246 Houndour
# 247 Houndoom
# 248 HoundoomMega Houndoom
# 249 Kingdra
# 250 Phanpy
# 251 Donphan
# 252 Porygon2
# 253 Stantler
# 254 Smeargle
# 255 Tyrogue
# 256 Hitmontop
# 257 Smoochum
# 258 Elekid
# 259 Magby
# 260 Miltank
# 261 Blissey
# 262 Raikou
# 263 Entei
# 264 Suicune
# 265 Larvitar
# 266 Pupitar
# 267 Tyranitar
# 268 TyranitarMega Tyranitar
# 269 Lugia
# 270 Ho-oh
# 271 Celebi
# 272 Treecko
# 273 Grovyle
# 274 Sceptile
# 275 SceptileMega Sceptile
# 276 Torchic
# 277 Combusken
# 278 Blaziken
# 279 BlazikenMega Blaziken
# 280 Mudkip
# 281 Marshtomp
# 282 Swampert
# 283 SwampertMega Swampert
# 284 Poochyena
# 285 Mightyena
# 286 Zigzagoon
# 287 Linoone
# 288 Wurmple
# 289 Silcoon
# 290 Beautifly
# 291 Cascoon
# 292 Dustox
# 293 Lotad
# 294 Lombre
# 295 Ludicolo
# 296 Seedot
# 297 Nuzleaf
# 298 Shiftry
# 299 Taillow
# 300 Swellow
# 301 Wingull
# 302 Pelipper
# 303 Ralts
# 304 Kirlia
# 305 Gardevoir
# 306 GardevoirMega Gardevoir
# 307 Surskit
# 308 Masquerain
# 309 Shroomish
# 310 Breloom
# 311 Slakoth
# 312 Vigoroth
# 313 Slaking
# 314 Nincada
# 315 Ninjask
# 316 Shedinja
# 317 Whismur
# 318 Loudred
# 319 Exploud
# 320 Makuhita
# 321 Hariyama
# 322 Azurill
# 323 Nosepass
# 324 Skitty
# 325 Delcatty
# 326 Sableye
# 327 SableyeMega Sableye
# 328 Mawile
# 329 MawileMega Mawile
# 330 Aron
# 331 Lairon
# 332 Aggron
# 333 AggronMega Aggron
# 334 Meditite
# 335 Medicham
# 336 MedichamMega Medicham
# 337 Electrike
# 338 Manectric
# 339 ManectricMega Manectric
# 340 Plusle
# 341 Minun
# 342 Volbeat
# 343 Illumise
# 344 Roselia
# 345 Gulpin
# 346 Swalot
# 347 Carvanha
# 348 Sharpedo
# 349 SharpedoMega Sharpedo
# 350 Wailmer
# 351 Wailord
# 352 Numel
# 353 Camerupt
# 354 CameruptMega Camerupt
# 355 Torkoal
# 356 Spoink
# 357 Grumpig
# 358 Spinda
# 359 Trapinch
# 360 Vibrava
# 361 Flygon
# 362 Cacnea
# 363 Cacturne
# 364 Swablu
# 365 Altaria
# 366 AltariaMega Altaria
# 367 Zangoose
# 368 Seviper
# 369 Lunatone
# 370 Solrock
# 371 Barboach
# 372 Whiscash
# 373 Corphish
# 374 Crawdaunt
# 375 Baltoy
# 376 Claydol
# 377 Lileep
# 378 Cradily
# 379 Anorith
# 380 Armaldo
# 381 Feebas
# 382 Milotic
# 383 Castform
# 384 Kecleon
# 385 Shuppet
# 386 Banette
# 387 BanetteMega Banette
# 388 Duskull
# 389 Dusclops
# 390 Tropius
# 391 Chimecho
# 392 Absol
# 393 AbsolMega Absol
# 394 Wynaut
# 395 Snorunt
# 396 Glalie
# 397 GlalieMega Glalie
# 398 Spheal
# 399 Sealeo
# 400 Walrein
# 401 Clamperl
# 402 Huntail
# 403 Gorebyss
# 404 Relicanth
# 405 Luvdisc
# 406 Bagon
# 407 Shelgon
# 408 Salamence
# 409 SalamenceMega Salamence
# 410 Beldum
# 411 Metang
# 412 Metagross
# 413 MetagrossMega Metagross
# 414 Regirock
# 415 Regice
# 416 Registeel
# 417 Latias
# 418 LatiasMega Latias
# 419 Latios
# 420 LatiosMega Latios
# 421 Kyogre
# 422 KyogrePrimal Kyogre
# 423 Groudon
# 424 GroudonPrimal Groudon
# 425 Rayquaza
# 426 RayquazaMega Rayquaza
# 427 Jirachi
# 428 DeoxysNormal Forme
# 429 DeoxysAttack Forme
# 430 DeoxysDefense Forme
# 431 DeoxysSpeed Forme
# 432 Turtwig
# 433 Grotle
# 434 Torterra
# 435 Chimchar
# 436 Monferno
# 437 Infernape
# 438 Piplup
# 439 Prinplup
# 440 Empoleon
# 441 Starly
# 442 Staravia
# 443 Staraptor
# 444 Bidoof
# 445 Bibarel
# 446 Kricketot
# 447 Kricketune
# 448 Shinx
# 449 Luxio
# 450 Luxray
# 451 Budew
# 452 Roserade
# 453 Cranidos
# 454 Rampardos
# 455 Shieldon
# 456 Bastiodon
# 457 Burmy
# 458 WormadamPlant Cloak
# 459 WormadamSandy Cloak
# 460 WormadamTrash Cloak
# 461 Mothim
# 462 Combee
# 463 Vespiquen
# 464 Pachirisu
# 465 Buizel
# 466 Floatzel
# 467 Cherubi
# 468 Cherrim
# 469 Shellos
# 470 Gastrodon
# 471 Ambipom
# 472 Drifloon
# 473 Drifblim
# 474 Buneary
# 475 Lopunny
# 476 LopunnyMega Lopunny
# 477 Mismagius
# 478 Honchkrow
# 479 Glameow
# 480 Purugly
# 481 Chingling
# 482 Stunky
# 483 Skuntank
# 484 Bronzor
# 485 Bronzong
# 486 Bonsly
# 487 Mime Jr.
# 488 Happiny
# 489 Chatot
# 490 Spiritomb
# 491 Gible
# 492 Gabite
# 493 Garchomp
# 494 GarchompMega Garchomp
# 495 Munchlax
# 496 Riolu
# 497 Lucario
# 498 LucarioMega Lucario
# 499 Hippopotas
# 500 Hippowdon
# 501 Skorupi
# 502 Drapion
# 503 Croagunk
# 504 Toxicroak
# 505 Carnivine
# 506 Finneon
# 507 Lumineon
# 508 Mantyke
# 509 Snover
# 510 Abomasnow
# 511 AbomasnowMega Abomasnow
# 512 Weavile
# 513 Magnezone
# 514 Lickilicky
# 515 Rhyperior
# 516 Tangrowth
# 517 Electivire
# 518 Magmortar
# 519 Togekiss
# 520 Yanmega
# 521 Leafeon
# 522 Glaceon
# 523 Gliscor
# 524 Mamoswine
# 525 Porygon-Z
# 526 Gallade
# 527 GalladeMega Gallade
# 528 Probopass
# 529 Dusknoir
# 530 Froslass
# 531 Rotom
# 532 RotomHeat Rotom
# 533 RotomWash Rotom
# 534 RotomFrost Rotom
# 535 RotomFan Rotom
# 536 RotomMow Rotom
# 537 Uxie
# 538 Mesprit
# 539 Azelf
# 540 Dialga
# 541 Palkia
# 542 Heatran
# 543 Regigigas
# 544 GiratinaAltered Forme
# 545 GiratinaOrigin Forme
# 546 Cresselia
# 547 Phione
# 548 Manaphy
# 549 Darkrai
# 550 ShayminLand Forme
# 551 ShayminSky Forme
# 552 Arceus
# 553 Victini
# 554 Snivy
# 555 Servine
# 556 Serperior
# 557 Tepig
# 558 Pignite
# 559 Emboar
# 560 Oshawott
# 561 Dewott
# 562 Samurott
# 563 Patrat
# 564 Watchog
# 565 Lillipup
# 566 Herdier
# 567 Stoutland
# 568 Purrloin
# 569 Liepard
# 570 Pansage
# 571 Simisage
# 572 Pansear
# 573 Simisear
# 574 Panpour
# 575 Simipour
# 576 Munna
# 577 Musharna
# 578 Pidove
# 579 Tranquill
# 580 Unfezant
# 581 Blitzle
# 582 Zebstrika
# 583 Roggenrola
# 584 Boldore
# 585 Gigalith
# 586 Woobat
# 587 Swoobat
# 588 Drilbur
# 589 Excadrill
# 590 Audino
# 591 AudinoMega Audino
# 592 Timburr
# 593 Gurdurr
# 594 Conkeldurr
# 595 Tympole
# 596 Palpitoad
# 597 Seismitoad
# 598 Throh
# 599 Sawk
# 600 Sewaddle
# 601 Swadloon
# 602 Leavanny
# 603 Venipede
# 604 Whirlipede
# 605 Scolipede
# 606 Cottonee
# 607 Whimsicott
# 608 Petilil
# 609 Lilligant
# 610 Basculin
# 611 Sandile
# 612 Krokorok
# 613 Krookodile
# 614 Darumaka
# 615 DarmanitanStandard Mode
# 616 DarmanitanZen Mode
# 617 Maractus
# 618 Dwebble
# 619 Crustle
# 620 Scraggy
# 621 Scrafty
# 622 Sigilyph
# 623 Yamask
# 624 Cofagrigus
# 625 Tirtouga
# 626 Carracosta
# 627 Archen
# 628 Archeops
# 629 Trubbish
# 630 Garbodor
# 631 Zorua
# 632 Zoroark
# 633 Minccino
# 634 Cinccino
# 635 Gothita
# 636 Gothorita
# 637 Gothitelle
# 638 Solosis
# 639 Duosion
# 640 Reuniclus
# 641 Ducklett
# 642 Swanna
# 643 Vanillite
# 644 Vanillish
# 645 Vanilluxe
# 646 Deerling
# 647 Sawsbuck
# 648 Emolga
# 649 Karrablast
# 650 Escavalier
# 651 Foongus
# 652 Amoonguss
# 653 Frillish
# 654 Jellicent
# 655 Alomomola
# 656 Joltik
# 657 Galvantula
# 658 Ferroseed
# 659 Ferrothorn
# 660 Klink
# 661 Klang
# 662 Klinklang
# 663 Tynamo
# 664 Eelektrik
# 665 Eelektross
# 666 Elgyem
# 667 Beheeyem
# 668 Litwick
# 669 Lampent
# 670 Chandelure
# 671 Axew
# 672 Fraxure
# 673 Haxorus
# 674 Cubchoo
# 675 Beartic
# 676 Cryogonal
# 677 Shelmet
# 678 Accelgor
# 679 Stunfisk
# 680 Mienfoo
# 681 Mienshao
# 682 Druddigon
# 683 Golett
# 684 Golurk
# 685 Pawniard
# 686 Bisharp
# 687 Bouffalant
# 688 Rufflet
# 689 Braviary
# 690 Vullaby
# 691 Mandibuzz
# 692 Heatmor
# 693 Durant
# 694 Deino
# 695 Zweilous
# 696 Hydreigon
# 697 Larvesta
# 698 Volcarona
# 699 Cobalion
# 700 Terrakion
# 701 Virizion
# 702 TornadusIncarnate Forme
# 703 TornadusTherian Forme
# 704 ThundurusIncarnate Forme
# 705 ThundurusTherian Forme
# 706 Reshiram
# 707 Zekrom
# 708 LandorusIncarnate Forme
# 709 LandorusTherian Forme
# 710 Kyurem
# 711 KyuremBlack Kyurem
# 712 KyuremWhite Kyurem
# 713 KeldeoOrdinary Forme
# 714 KeldeoResolute Forme
# 715 MeloettaAria Forme
# 716 MeloettaPirouette Forme
# 717 Genesect
# 718 Chespin
# 719 Quilladin
# 720 Chesnaught
# 721 Fennekin
# 722 Braixen
# 723 Delphox
# 724 Froakie
# 725 Frogadier
# 726 Greninja
# 727 Bunnelby
# 728 Diggersby
# 729 Fletchling
# 730 Fletchinder
# 731 Talonflame
# 732 Scatterbug
# 733 Spewpa
# 734 Vivillon
# 735 Litleo
# 736 Pyroar
# 737 Flabébé
# 738 Floette
# 739 Florges
# 740 Skiddo
# 741 Gogoat
# 742 Pancham
# 743 Pangoro
# 744 Furfrou
# 745 Espurr
# 746 MeowsticMale
# 747 MeowsticFemale
# 748 Honedge
# 749 Doublade
# 750 AegislashBlade Forme
# 751 AegislashShield Forme
# 752 Spritzee
# 753 Aromatisse
# 754 Swirlix
# 755 Slurpuff
# 756 Inkay
# 757 Malamar
# 758 Binacle
# 759 Barbaracle
# 760 Skrelp
# 761 Dragalge
# 762 Clauncher
# 763 Clawitzer
# 764 Helioptile
# 765 Heliolisk
# 766 Tyrunt
# 767 Tyrantrum
# 768 Amaura
# 769 Aurorus
# 770 Sylveon
# 771 Hawlucha
# 772 Dedenne
# 773 Carbink
# 774 Goomy
# 775 Sliggoo
# 776 Goodra
# 777 Klefki
# 778 Phantump
# 779 Trevenant
# 780 PumpkabooAverage Size
# 781 PumpkabooSmall Size
# 782 PumpkabooLarge Size
# 783 PumpkabooSuper Size
# 784 GourgeistAverage Size
# 785 GourgeistSmall Size
# 786 GourgeistLarge Size
# 787 GourgeistSuper Size
# 788 Bergmite
# 789 Avalugg
# 790 Noibat
# 791 Noivern
# 792 Xerneas
# 793 Yveltal
# 794 Zygarde50% Forme
# 795 Diancie
# 796 DiancieMega Diancie
# 797 HoopaHoopa Confined
# 798 HoopaHoopa Unbound
# 799 Volcanion

# %%
#Using loc to access any type of data
df.loc[df['Type 1'] == "Grass"]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 48        75       65     30           1      False
# ..       ...      ...    ...         ...        ...
# 718       48       45     38           6      False
# 719       56       58     57           6      False
# 720       74       75     64           6      False
# 740       62       57     52           6      False
# 741       97       81     68           6      False
#
# [70 rows x 12 columns]

# %%
#Using loc to access any type of data
df.loc[df['Type 1'] == "Fighting"]
# Out:
#        #                   Name    Type 1   Type 2   HP  Attack  Defense  \
# 61    56                 Mankey  Fighting      NaN   40      80       35
# 62    57               Primeape  Fighting      NaN   65     105       60
# 72    66                 Machop  Fighting      NaN   70      80       50
# 73    67                Machoke  Fighting      NaN   80     100       70
# 74    68                Machamp  Fighting      NaN   90     130       80
# 114  106              Hitmonlee  Fighting      NaN   50     120       53
# 115  107             Hitmonchan  Fighting      NaN   50     105       79
# 255  236                Tyrogue  Fighting      NaN   35      35       35
# 256  237              Hitmontop  Fighting      NaN   50      95       95
# 320  296               Makuhita  Fighting      NaN   72      60       30
# 321  297               Hariyama  Fighting      NaN  144     120       60
# 334  307               Meditite  Fighting  Psychic   30      40       55
# 335  308               Medicham  Fighting  Psychic   60      60       75
# 336  308  MedichamMega Medicham  Fighting  Psychic   60     100       85
# 496  447                  Riolu  Fighting      NaN   40      70       40
# 497  448                Lucario  Fighting    Steel   70     110       70
# 498  448    LucarioMega Lucario  Fighting    Steel   70     145       88
# 592  532                Timburr  Fighting      NaN   75      80       55
# 593  533                Gurdurr  Fighting      NaN   85     105       85
# 594  534             Conkeldurr  Fighting      NaN  105     140       95
# 598  538                  Throh  Fighting      NaN  120     100       85
# 599  539                   Sawk  Fighting      NaN   75     125       75
# 680  619                Mienfoo  Fighting      NaN   45      85       50
# 681  620               Mienshao  Fighting      NaN   65     125       60
# 742  674                Pancham  Fighting      NaN   67      82       62
# 743  675                Pangoro  Fighting     Dark   95     124       78
# 771  701               Hawlucha  Fighting   Flying   78      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 61        35       45     70           1      False
# 62        60       70     95           1      False
# 72        35       35     35           1      False
# 73        50       60     45           1      False
# 74        65       85     55           1      False
# 114       35      110     87           1      False
# 115       35      110     76           1      False
# 255       35       35     35           2      False
# 256       35      110     70           2      False
# 320       20       30     25           3      False
# 321       40       60     50           3      False
# 334       40       55     60           3      False
# 335       60       75     80           3      False
# 336       80       85    100           3      False
# 496       35       40     60           4      False
# 497      115       70     90           4      False
# 498      140       70    112           4      False
# 592       25       35     35           5      False
# 593       40       50     40           5      False
# 594       55       65     45           5      False
# 598       30       85     45           5      False
# 599       30       75     85           5      False
# 680       55       50     65           5      False
# 681       95       60    105           5      False
# 742       46       48     43           6      False
# 743       69       71     58           6      False
# 771       74       63    118           6      False

# %%
#Sorting Describing Data
#Provide statistics based on mean,median etc
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
#Sort Values
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       92       85     60           4      False
# 511      132      105     30           4      False
# 68       105       55     90           1      False
# 392       75       60     75           3      False
# 393      115       60    115           3      False
# ..       ...      ...    ...         ...        ...
# 632      120       60    105           5      False
# 631       80       40     65           5      False
# 46        30       40     55           1      False
# 695       65       70     58           5      False
# 794       81       95     95           6       True
#
# [800 rows x 12 columns]

# %%
#Sort Values
df.sort_values('Name',ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 695       65       70     58           5      False
# 46        30       40     55           1      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# ..       ...      ...    ...         ...        ...
# 393      115       60    115           3      False
# 392       75       60     75           3      False
# 68       105       55     90           1      False
# 511      132      105     30           4      False
# 510       92       85     60           4      False
#
# [800 rows x 12 columns]

# %%
#Sorting on multiple values using asc,desc
df.sort_values(['Type 1','HP'])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# 316     40           3      False
# 230      5           2      False
# 462     70           4      False
# 603     57           5      False
# 314     40           3      False
# ..     ...         ...        ...
# 142     60           1      False
# 145     65           1      False
# 350     60           3      False
# 655     65           5      False
# 351     60           3      False
#
# [800 rows x 12 columns]

# %%
#Sorting on multiple values using asc,desc
df.sort_values(['Type 1','HP'],ascending=[0,0])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 351  321    Wailord  Water     NaN  170      90       45       90       45
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# 351     60           3      False
# 655     65           5      False
# 142     60           1      False
# 145     65           1      False
# 350     60           3      False
# ..     ...         ...        ...
# 314     40           3      False
# 462     70           4      False
# 603     57           5      False
# 230      5           2      False
# 316     40           3      False
#
# [800 rows x 12 columns]

# %%
#Making Changes to the Data
#Adding the sum
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  ...  Sp. Atk  Sp. Def  \
# 0  1              Bulbasaur  Grass  Poison  45      49  ...       65       65
# 1  2                Ivysaur  Grass  Poison  60      62  ...       80       80
# 2  3               Venusaur  Grass  Poison  80      82  ...      100      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100  ...      122      120
# 4  4             Charmander   Fire     NaN  39      52  ...       60       50
#
#    Speed  Generation  Legendary  Total
# 0     45           1      False    208
# 1     60           1      False    265
# 2     80           1      False    345
# 3     80           1      False    425
# 4     65           1      False    194
#
# [5 rows x 13 columns]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  ...  Sp. Atk  \
# 0      1              Bulbasaur    Grass  Poison  45      49  ...       65
# 1      2                Ivysaur    Grass  Poison  60      62  ...       80
# 2      3               Venusaur    Grass  Poison  80      82  ...      100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100  ...      122
# 4      4             Charmander     Fire     NaN  39      52  ...       60
# ..   ...                    ...      ...     ...  ..     ...  ...      ...
# 795  719                Diancie     Rock   Fairy  50     100  ...      100
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160  ...      160
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110  ...      150
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160  ...      170
# 799  721              Volcanion     Fire   Water  80     110  ...      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 0         65     45           1      False    208
# 1         80     60           1      False    265
# 2        100     80           1      False    345
# 3        120     80           1      False    425
# 4         50     65           1      False    194
# ..       ...    ...         ...        ...    ...
# 795      150     50           6       True    400
# 796      110    110           6       True    480
# 797      130     70           6       True    400
# 798      130     80           6       True    470
# 799       90     70           6       True    440
#
# [800 rows x 13 columns]

# %%
#axis = 0 means along the column and axis = 1 means working along the row.
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  ...  Sp. Atk  Sp. Def  \
# 0  1              Bulbasaur  Grass  Poison  45      49  ...       65       65
# 1  2                Ivysaur  Grass  Poison  60      62  ...       80       80
# 2  3               Venusaur  Grass  Poison  80      82  ...      100      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100  ...      122      120
# 4  4             Charmander   Fire     NaN  39      52  ...       60       50
#
#    Speed  Generation  Legendary  Total
# 0     45           1      False    318
# 1     60           1      False    405
# 2     80           1      False    525
# 3     80           1      False    625
# 4     65           1      False    309
#
# [5 rows x 13 columns]

# %%
#Displaying columns in rearrangement,this does not modify the data,its visual
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  ...  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison    318  45  ...       49       65
# 1  2                Ivysaur  Grass  Poison    405  60  ...       63       80
# 2  3               Venusaur  Grass  Poison    525  80  ...       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80  ...      123      122
# 4  4             Charmander   Fire     NaN    309  39  ...       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#
# [5 rows x 13 columns]

# %%
#Droping a column
df = df.drop(columns=['Total'])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
#Making Changes to the Data
#Adding the sum
import pandas as pd
df=pd.read_csv('pokemon_data.csv')
print(df)
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk']
df.head(5)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]
#    #                   Name Type 1  Type 2  HP  Attack  ...  Sp. Atk  Sp. Def  \
# 0  1              Bulbasaur  Grass  Poison  45      49  ...       65       65
# 1  2                Ivysaur  Grass  Poison  60      62  ...       80       80
# 2  3               Venusaur  Grass  Poison  80      82  ...      100      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100  ...      122      120
# 4  4             Charmander   Fire     NaN  39      52  ...       60       50
#
#    Speed  Generation  Legendary  Total
# 0     45           1      False    208
# 1     60           1      False    265
# 2     80           1      False    345
# 3     80           1      False    425
# 4     65           1      False    194
#
# [5 rows x 13 columns]

# %%
#axis = 0 means along the column and axis = 1 means working along the row.
df['Total1'] = df.iloc[:, 4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  ...  Sp. Def  Speed  \
# 0  1              Bulbasaur  Grass  Poison  45      49  ...       65     45
# 1  2                Ivysaur  Grass  Poison  60      62  ...       80     60
# 2  3               Venusaur  Grass  Poison  80      82  ...      100     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100  ...      120     80
# 4  4             Charmander   Fire     NaN  39      52  ...       50     65
#
#    Generation  Legendary  Total  Total1
# 0           1      False    208     318
# 1           1      False    265     405
# 2           1      False    345     525
# 3           1      False    425     625
# 4           1      False    194     309
#
# [5 rows x 14 columns]

# %%
#Displaying columns in rearrangement,this does not modify the data,its visual
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total1  HP  ...  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison     318  45  ...       49       65
# 1  2                Ivysaur  Grass  Poison     405  60  ...       63       80
# 2  3               Venusaur  Grass  Poison     525  80  ...       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison     625  80  ...      123      122
# 4  4             Charmander   Fire     NaN     309  39  ...       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#
# [5 rows x 13 columns]

# %%
# Saving our data,Exporting into desired format
df.to_csv('modified.csv')

# %%
#Saved in a .csv format,without indexes
df.to_csv('modified1.csv',index=False)

# %%
#Saving in a excel format
df.to_excel('modified.xlsx', index=False)

#Saving in a excel format
#df.to_excel('modified.xlsx',sep='\t',index=False)

#read in a excel format
#df=pd.read_excel('modified.xlsx', index_col='Response')

# %%
#Reading data from an xlsx excel file
df_xlsx=pd.read_excel('modified.xlsx')
print(df_xlsx.head(3))
# Out:
#    #       Name Type 1  Type 2  Total1  HP  ...  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison     318  45  ...       49       65       65
# 1  2    Ivysaur  Grass  Poison     405  60  ...       63       80       80
# 2  3   Venusaur  Grass  Poison     525  80  ...       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
#
# [3 rows x 13 columns]

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
#Saving in a txt doc which is tab separated
df.to_csv('modified.txt', index=False, sep='\t')

# %%
#Filtering data using & and |
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') ]
new_df
# Out:
#        #                   Name Type 1  Type 2  Total1   HP  ...  Defense  \
# 0      1              Bulbasaur  Grass  Poison     318   45  ...       49
# 1      2                Ivysaur  Grass  Poison     405   60  ...       63
# 2      3               Venusaur  Grass  Poison     525   80  ...       83
# 3      3  VenusaurMega Venusaur  Grass  Poison     625   80  ...      123
# 48    43                 Oddish  Grass  Poison     320   45  ...       55
# 49    44                  Gloom  Grass  Poison     395   60  ...       70
# 50    45              Vileplume  Grass  Poison     490   75  ...       85
# 75    69             Bellsprout  Grass  Poison     300   50  ...       35
# 76    70             Weepinbell  Grass  Poison     390   65  ...       50
# 77    71             Victreebel  Grass  Poison     490   80  ...       65
# 344  315                Roselia  Grass  Poison     400   50  ...       45
# 451  406                  Budew  Grass  Poison     280   40  ...       35
# 452  407               Roserade  Grass  Poison     515   60  ...       65
# 651  590                Foongus  Grass  Poison     294   69  ...       45
# 652  591              Amoonguss  Grass  Poison     464  114  ...       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 48        75       65     30           1      False
# 49        85       75     40           1      False
# 50       110       90     50           1      False
# 75        70       30     40           1      False
# 76        85       45     55           1      False
# 77       100       70     70           1      False
# 344      100       80     65           3      False
# 451       50       70     55           4      False
# 452      125      105     90           4      False
# 651       55       55     15           5      False
# 652       85       80     30           5      False
#
# [15 rows x 13 columns]

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['Speed']==40)]
new_df
# Out:
#      #        Name Type 1  Type 2  Total1  HP  ...  Defense  Sp. Atk  Sp. Def  \
# 49  44       Gloom  Grass  Poison     395  60  ...       70       85       75
# 75  69  Bellsprout  Grass  Poison     300  50  ...       35       70       30
#
#     Speed  Generation  Legendary
# 49     40           1      False
# 75     40           1      False
#
# [2 rows x 13 columns]

# %%
new_df1 = (df['Name'] == 'Skiddo')
df[new_df1]
# Out:
#        #    Name Type 1 Type 2  Total1  HP  ...  Defense  Sp. Atk  Sp. Def  \
# 740  672  Skiddo  Grass    NaN     350  66  ...       48       62       57
#
#      Speed  Generation  Legendary
# 740     52           6      False
#
# [1 rows x 13 columns]

# %%
#Saving the filtered data
new_df.to_csv('filtered.csv')

# %%
df1=pd.read_csv('filtered.csv')
print(df1)
# Out:
#    Unnamed: 0   #        Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 0          49  44       Gloom  Grass  Poison     395  ...       70       85
# 1          75  69  Bellsprout  Grass  Poison     300  ...       35       70
#
#    Sp. Def  Speed  Generation  Legendary
# 0       75     40           1      False
# 1       30     40           1      False
#
# [2 rows x 14 columns]

# %%
#Resetting indexes
#inplace = True , the data is modified in place, which means it will return n
#and the dataframe is now updated. When inplace = False ,
#which is the default, then the operation is performed and it returns a copy
new_df.reset_index(drop=True, inplace=False)
new_df
# Out:
#      #        Name Type 1  Type 2  Total1  HP  ...  Defense  Sp. Atk  Sp. Def  \
# 49  44       Gloom  Grass  Poison     395  60  ...       70       85       75
# 75  69  Bellsprout  Grass  Poison     300  50  ...       35       70       30
#
#     Speed  Generation  Legendary
# 49     40           1      False
# 75     40           1      False
#
# [2 rows x 13 columns]

# %%
#Resetting indexes
#inplace = True , the data is modified in place, which means it will return n
#and the dataframe is now updated. When inplace = False ,
#which is the default, then the operation is performed and it returns a copy
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#     #        Name Type 1  Type 2  Total1  HP  ...  Defense  Sp. Atk  Sp. Def  \
# 0  44       Gloom  Grass  Poison     395  60  ...       70       85       75
# 1  69  Bellsprout  Grass  Poison     300  50  ...       35       70       30
#
#    Speed  Generation  Legendary
# 0     40           1      False
# 1     40           1      False
#
# [2 rows x 13 columns]

# %%
new_df.rename(columns={'Name':'first_name'}, inplace=True)
new_df
# Out:
# <ipython-input-94-ca450e236d71>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'Name':'first_name'}, inplace=True)
#     #  first_name Type 1  Type 2  Total1  HP  ...  Defense  Sp. Atk  Sp. Def  \
# 0  44       Gloom  Grass  Poison     395  60  ...       70       85       75
# 1  69  Bellsprout  Grass  Poison     300  50  ...       35       70       30
#
#    Speed  Generation  Legendary
# 0     40           1      False
# 1     40           1      False
#
# [2 rows x 13 columns]

# %%
df1=pd.read_csv('filtered.csv')
print(df1)
# Out:
#    Unnamed: 0   #        Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 0          49  44       Gloom  Grass  Poison     395  ...       70       85
# 1          75  69  Bellsprout  Grass  Poison     300  ...       35       70
#
#    Sp. Def  Speed  Generation  Legendary
# 0       75     40           1      False
# 1       30     40           1      False
#
# [2 rows x 14 columns]

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
new_df
# Out:
#        #                   Name Type 1    Type 2  Total1   HP  ...  Defense  \
# 0      1              Bulbasaur  Grass    Poison     318   45  ...       49
# 1      2                Ivysaur  Grass    Poison     405   60  ...       63
# 2      3               Venusaur  Grass    Poison     525   80  ...       83
# 3      3  VenusaurMega Venusaur  Grass    Poison     625   80  ...      123
# 16    13                 Weedle    Bug    Poison     195   40  ...       30
# ..   ...                    ...    ...       ...     ...  ...  ...      ...
# 718  650                Chespin  Grass       NaN     313   56  ...       65
# 719  651              Quilladin  Grass       NaN     405   61  ...       95
# 720  652             Chesnaught  Grass  Fighting     530   88  ...      122
# 740  672                 Skiddo  Grass       NaN     350   66  ...       48
# 741  673                 Gogoat  Grass       NaN     531  123  ...       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 16        20       20     50           1      False
# ..       ...      ...    ...         ...        ...
# 718       48       45     38           6      False
# 719       56       58     57           6      False
# 720       74       75     64           6      False
# 740       62       57     52           6      False
# 741       97       81     68           6      False
#
# [89 rows x 13 columns]

# %%
#String functions
df['Name']=df['Name'].str.lower()
df
# Out:
#        #                   Name   Type 1  Type 2  Total1  HP  ...  Defense  \
# 0      1              bulbasaur    Grass  Poison     318  45  ...       49
# 1      2                ivysaur    Grass  Poison     405  60  ...       63
# 2      3               venusaur    Grass  Poison     525  80  ...       83
# 3      3  venusaurmega venusaur    Grass  Poison     625  80  ...      123
# 4      4             charmander     Fire     NaN     309  39  ...       43
# ..   ...                    ...      ...     ...     ...  ..  ...      ...
# 795  719                diancie     Rock   Fairy     600  50  ...      150
# 796  719    dianciemega diancie     Rock   Fairy     700  50  ...      110
# 797  720    hoopahoopa confined  Psychic   Ghost     600  80  ...       60
# 798  720     hoopahoopa unbound  Psychic    Dark     680  80  ...       60
# 799  721              volcanion     Fire   Water     600  80  ...      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
#String functions
df['Name']=df['Name'].str.upper()
df
# Out:
#        #                   Name   Type 1  Type 2  Total1  HP  ...  Defense  \
# 0      1              BULBASAUR    Grass  Poison     318  45  ...       49
# 1      2                IVYSAUR    Grass  Poison     405  60  ...       63
# 2      3               VENUSAUR    Grass  Poison     525  80  ...       83
# 3      3  VENUSAURMEGA VENUSAUR    Grass  Poison     625  80  ...      123
# 4      4             CHARMANDER     Fire     NaN     309  39  ...       43
# ..   ...                    ...      ...     ...     ...  ..  ...      ...
# 795  719                DIANCIE     Rock   Fairy     600  50  ...      150
# 796  719    DIANCIEMEGA DIANCIE     Rock   Fairy     700  50  ...      110
# 797  720    HOOPAHOOPA CONFINED  Psychic   Ghost     600  80  ...       60
# 798  720     HOOPAHOOPA UNBOUND  Psychic    Dark     680  80  ...       60
# 799  721              VOLCANION     Fire   Water     600  80  ...      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
#Filtering data based on criteria using contains function
df.loc[df['Name'].str.contains('Mega')]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total1, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []
#
# [0 rows x 13 columns]

# %%
#Filtering data based on criteria using contains function-using negation
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                   Name   Type 1  Type 2  Total1  HP  ...  Defense  \
# 0      1              BULBASAUR    Grass  Poison     318  45  ...       49
# 1      2                IVYSAUR    Grass  Poison     405  60  ...       63
# 2      3               VENUSAUR    Grass  Poison     525  80  ...       83
# 3      3  VENUSAURMEGA VENUSAUR    Grass  Poison     625  80  ...      123
# 4      4             CHARMANDER     Fire     NaN     309  39  ...       43
# ..   ...                    ...      ...     ...     ...  ..  ...      ...
# 795  719                DIANCIE     Rock   Fairy     600  50  ...      150
# 796  719    DIANCIEMEGA DIANCIE     Rock   Fairy     700  50  ...      110
# 797  720    HOOPAHOOPA CONFINED  Psychic   Ghost     600  80  ...       60
# 798  720     HOOPAHOOPA UNBOUND  Psychic    Dark     680  80  ...       60
# 799  721              VOLCANION     Fire   Water     600  80  ...      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
#Using regex
import re
df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total1   HP  ...  Defense  \
# 0      1              BULBASAUR  Grass  Poison     318   45  ...       49
# 1      2                IVYSAUR  Grass  Poison     405   60  ...       63
# 2      3               VENUSAUR  Grass  Poison     525   80  ...       83
# 3      3  VENUSAURMEGA VENUSAUR  Grass  Poison     625   80  ...      123
# 4      4             CHARMANDER   Fire     NaN     309   39  ...       43
# ..   ...                    ...    ...     ...     ...  ...  ...      ...
# 735  667                 LITLEO   Fire  Normal     369   62  ...       58
# 736  668                 PYROAR   Fire  Normal     507   86  ...       72
# 740  672                 SKIDDO  Grass     NaN     350   66  ...       48
# 741  673                 GOGOAT  Grass     NaN     531  123  ...       62
# 799  721              VOLCANION   Fire   Water     600   80  ...      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 735       73       54     72           6      False
# 736      109       66    106           6      False
# 740       62       57     52           6      False
# 741       97       81     68           6      False
# 799      130       90     70           6       True
#
# [122 rows x 13 columns]

# %%
#Get names that start with Pi,* means 0 or more
df.loc[df['Name'].str.contains('^Pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total1   HP  ...  Defense  \
# 20    16               PIDGEY    Normal    Flying     251   40  ...       40
# 21    17            PIDGEOTTO    Normal    Flying     349   63  ...       55
# 22    18              PIDGEOT    Normal    Flying     479   83  ...       75
# 23    18  PIDGEOTMEGA PIDGEOT    Normal    Flying     579   83  ...       80
# 30    25              PIKACHU  Electric       NaN     320   35  ...       40
# 136  127               PINSIR       Bug       NaN     500   65  ...      100
# 137  127    PINSIRMEGA PINSIR       Bug    Flying     600   65  ...      120
# 186  172                PICHU  Electric       NaN     205   20  ...       15
# 219  204               PINECO       Bug       NaN     290   50  ...       90
# 239  221            PILOSWINE       Ice    Ground     450  100  ...       80
# 438  393               PIPLUP     Water       NaN     314   53  ...       53
# 558  499              PIGNITE      Fire  Fighting     418   90  ...       55
# 578  519               PIDOVE    Normal    Flying     264   50  ...       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20        35       35     56           1      False
# 21        50       50     71           1      False
# 22        70       70    101           1      False
# 23       135       80    121           1      False
# 30        50       50     90           1      False
# 136       55       70     85           1      False
# 137       65       90    105           1      False
# 186       35       35     60           2      False
# 219       35       35     15           2      False
# 239       60       60     50           2      False
# 438       61       56     40           4      False
# 558       70       55     55           5      False
# 578       36       30     43           5      False
#
# [13 rows x 13 columns]

# %%
#Conditional Changes
#Change the data based on conditions
df.loc[df['Type 1']=='Fire','Type 1']='Error'
df
# Out:
#        #                   Name   Type 1  Type 2  Total1  HP  ...  Defense  \
# 0      1              BULBASAUR    Grass  Poison     318  45  ...       49
# 1      2                IVYSAUR    Grass  Poison     405  60  ...       63
# 2      3               VENUSAUR    Grass  Poison     525  80  ...       83
# 3      3  VENUSAURMEGA VENUSAUR    Grass  Poison     625  80  ...      123
# 4      4             CHARMANDER    Error     NaN     309  39  ...       43
# ..   ...                    ...      ...     ...     ...  ..  ...      ...
# 795  719                DIANCIE     Rock   Fairy     600  50  ...      150
# 796  719    DIANCIEMEGA DIANCIE     Rock   Fairy     700  50  ...      110
# 797  720    HOOPAHOOPA CONFINED  Psychic   Ghost     600  80  ...       60
# 798  720     HOOPAHOOPA UNBOUND  Psychic    Dark     680  80  ...       60
# 799  721              VOLCANION    Error   Water     600  80  ...      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
#chnage the value of the coloumn
df.loc[df['Total1'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']
df
# Out:
# <ipython-input-104-28e45ac44fea>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Test 1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total1'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']
# <ipython-input-104-28e45ac44fea>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Test 2' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total1'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']
#        #                   Name   Type 1  Type 2  Total1  HP  ...  Defense  \
# 0      1              BULBASAUR    Grass  Poison     318  45  ...       49
# 1      2                IVYSAUR    Grass  Poison     405  60  ...       63
# 2      3               VENUSAUR    Grass  Poison     525  80  ...       83
# 3      3  VENUSAURMEGA VENUSAUR    Grass  Poison     625  80  ...      123
# 4      4             CHARMANDER    Error     NaN     309  39  ...       43
# ..   ...                    ...      ...     ...     ...  ..  ...      ...
# 795  719                DIANCIE     Rock   Fairy     600  50  ...      150
# 796  719    DIANCIEMEGA DIANCIE     Rock   Fairy     700  50  ...      110
# 797  720    HOOPAHOOPA CONFINED  Psychic   Ghost     600  80  ...       60
# 798  720     HOOPAHOOPA UNBOUND  Psychic    Dark     680  80  ...       60
# 799  721              VOLCANION    Error   Water     600  80  ...      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0         65       65     45           1     False
# 1         80       80     60           1     False
# 2        100      100     80      Test 1    Test 2
# 3        122      120     80      Test 1    Test 2
# 4         60       50     65           1     False
# ..       ...      ...    ...         ...       ...
# 795      100      150     50      Test 1    Test 2
# 796      160      110    110      Test 1    Test 2
# 797      150      130     70      Test 1    Test 2
# 798      170      130     80      Test 1    Test 2
# 799      130       90     70      Test 1    Test 2
#
# [800 rows x 13 columns]

# %%
#reading the data
df=pd.read_csv('modified.csv')
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total1  ...  \
# 0             0    1              Bulbasaur    Grass  Poison     318  ...
# 1             1    2                Ivysaur    Grass  Poison     405  ...
# 2             2    3               Venusaur    Grass  Poison     525  ...
# 3             3    3  VenusaurMega Venusaur    Grass  Poison     625  ...
# 4             4    4             Charmander     Fire     NaN     309  ...
# ..          ...  ...                    ...      ...     ...     ...  ...
# 795         795  719                Diancie     Rock   Fairy     600  ...
# 796         796  719    DiancieMega Diancie     Rock   Fairy     700  ...
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost     600  ...
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark     680  ...
# 799         799  721              Volcanion     Fire   Water     600  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# 1         63       80       80     60           1      False
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 4         43       60       50     65           1      False
# ..       ...      ...      ...    ...         ...        ...
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [800 rows x 14 columns]

# %%
#Applying groupby with the sum function
df.groupby(['Type 1']).sum()
# Out:
#           Unnamed: 0      #  \
# Type 1
# Bug            25397  23080
# Dark           15729  14302
# Dragon         16699  15180
# Electric       17626  15994
# Fairy           8407   7642
# Fighting       10812   9824
# Fire           18769  17025
# Flying          2986   2711
# Ghost          17161  15568
# Grass          26629  24141
# Ground         12554  11401
# Ice            11176  10165
# Normal         34455  31279
# Poison          7792   7050
# Psychic        23946  21706
# Rock           19001  17280
# Steel          13130  11957
# Water          37331  33946
#
#                                                        Name  \
# Type 1
# Bug       CaterpieMetapodButterfreeWeedleKakunaBeedrillB...
# Dark      UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...
# Dragon    DratiniDragonairDragoniteAltariaAltariaMega Al...
# Electric  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...
# Fairy     ClefairyClefableCleffaTogepiTogeticSnubbullGra...
# Fighting  MankeyPrimeapeMachopMachokeMachampHitmonleeHit...
# Fire      CharmanderCharmeleonCharizardCharizardMega Cha...
# Flying    TornadusIncarnate FormeTornadusTherian FormeNo...
# Ghost     GastlyHaunterGengarGengarMega GengarMisdreavus...
# Grass     BulbasaurIvysaurVenusaurVenusaurMega VenusaurO...
# Ground    SandshrewSandslashDiglettDugtrioCuboneMarowakR...
# Ice       JynxArticunoSwinubPiloswineDelibirdSmoochumSno...
# Normal    PidgeyPidgeottoPidgeotPidgeotMega PidgeotRatta...
# Poison    EkansArbokNidoran (Female)NidorinaNidoqueenNid...
# Psychic   AbraKadabraAlakazamAlakazamMega AlakazamDrowze...
# Rock      GeodudeGravelerGolemOnixOmanyteOmastarKabutoKa...
# Steel     SteelixSteelixMega SteelixSkarmoryMawileMawile...
# Water     SquirtleWartortleBlastoiseBlastoiseMega Blasto...
#
#                                                      Type 2  Total1    HP  \
# Type 1
# Bug       FlyingPoisonPoisonPoisonPoisonGrassGrassPoison...   26146  3925
# Dark      FlyingIceFireFireFireGhostGhostFlyingIceFighti...   13818  2071
# Dragon    FlyingFlyingFairyFlyingFlyingPsychicPsychicPsy...   17617  2666
# Electric  SteelSteelFlyingDragonSteelGhostFireWaterIceFl...   19510  2631
# Fairy                                          FlyingFlying    7024  1260
# Fighting          PsychicPsychicPsychicSteelSteelDarkFlying   11244  1886
# Fire      FlyingDragonFlyingFlyingRockFlyingFightingFigh...   23820  3635
# Flying                                         DragonDragon    1940   283
# Ghost     PoisonPoisonPoisonPoisonFlyingFlyingDarkDragon...   14066  2062
# Grass     PoisonPoisonPoisonPoisonPoisonPoisonPoisonPois...   29480  4709
# Ground    RockRockFlyingDragonDragonPsychicPsychicFireRo...   14000  2361
# Ice       PsychicFlyingGroundGroundFlyingPsychicWaterWat...   10403  1728
# Normal    FlyingFlyingFlyingFlyingFlyingFlyingFairyFairy...   39365  7573
# Poison    GroundGroundFlyingFlyingFlyingDarkDarkBugDarkF...   11176  1883
# Psychic   FairyFightingFlyingFlyingFlyingGrassFairyFairy...   27129  4026
# Rock      GroundGroundGroundGroundWaterWaterWaterWaterFl...   19965  2876
# Steel     GroundGroundFlyingFairyFairyRockRockRockPsychi...   13168  1761
# Water     FightingPoisonPoisonPsychicPsychicPsychicIceIc...   48211  8071
#
#           ...  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1    ...
# Bug       ...     4880     3717     4471   4256         222          0
# Dark      ...     2177     2314     2155   2361         125          2
# Dragon    ...     2764     3099     2843   2657         124         12
# Electric  ...     2917     3961     3243   3718         144          4
# Fairy     ...     1117     1335     1440    826          70          1
# Fighting  ...     1780     1434     1747   1784          91          0
# Fire      ...     3524     4627     3755   3871         167          5
# Flying    ...      265      377      290    410          22          2
# Ghost     ...     2598     2539     2447   2059         134          2
# Grass     ...     4956     5425     4930   4335         235          3
# Ground    ...     2715     1807     2008   2045         101          4
# Ice       ...     1714     1861     1831   1523          85          2
# Normal    ...     5865     5470     6245   7012         299          2
# Poison    ...     1927     1692     1803   1780          71          0
# Psychic   ...     3858     5609     4918   4645         193         14
# Rock      ...     4435     2787     3321   2460         152          4
# Steel     ...     3412     1823     2177   1492         104          4
# Water     ...     8170     8379     7898   7388         320          4
#
# [18 rows x 13 columns]

# %%
#Applying groupby with count
df.groupby(['Type 1']).count()
# Out:
#           Unnamed: 0    #  Name  Type 2  Total1   HP  ...  Defense  Sp. Atk  \
# Type 1                                                ...
# Bug               69   69    69      52      69   69  ...       69       69
# Dark              31   31    31      21      31   31  ...       31       31
# Dragon            32   32    32      21      32   32  ...       32       32
# Electric          44   44    44      17      44   44  ...       44       44
# Fairy             17   17    17       2      17   17  ...       17       17
# Fighting          27   27    27       7      27   27  ...       27       27
# Fire              52   52    52      24      52   52  ...       52       52
# Flying             4    4     4       2       4    4  ...        4        4
# Ghost             32   32    32      22      32   32  ...       32       32
# Grass             70   70    70      37      70   70  ...       70       70
# Ground            32   32    32      19      32   32  ...       32       32
# Ice               24   24    24      11      24   24  ...       24       24
# Normal            98   98    98      37      98   98  ...       98       98
# Poison            28   28    28      13      28   28  ...       28       28
# Psychic           57   57    57      19      57   57  ...       57       57
# Rock              44   44    44      35      44   44  ...       44       44
# Steel             27   27    27      22      27   27  ...       27       27
# Water            112  112   112      53     112  112  ...      112      112
#
#           Sp. Def  Speed  Generation  Legendary
# Type 1
# Bug            69     69          69         69
# Dark           31     31          31         31
# Dragon         32     32          32         32
# Electric       44     44          44         44
# Fairy          17     17          17         17
# Fighting       27     27          27         27
# Fire           52     52          52         52
# Flying          4      4           4          4
# Ghost          32     32          32         32
# Grass          70     70          70         70
# Ground         32     32          32         32
# Ice            24     24          24         24
# Normal         98     98          98         98
# Poison         28     28          28         28
# Psychic        57     57          57         57
# Rock           44     44          44         44
# Steel          27     27          27         27
# Water         112    112         112        112
#
# [18 rows x 13 columns]

# %%
#Applying groupby with count
df['count']=1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
#Applying groupby with count on multiple columns
df['count']=1
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
import pandas as pd
for df in pd.read_csv('modified.csv',chunksize=5):
 print("Chunk DF")
 print(df)
# Out:
# Chunk DF
#    Unnamed: 0  #                   Name Type 1  Type 2  Total1  ...  Defense  \
# 0           0  1              Bulbasaur  Grass  Poison     318  ...       49
# 1           1  2                Ivysaur  Grass  Poison     405  ...       63
# 2           2  3               Venusaur  Grass  Poison     525  ...       83
# 3           3  3  VenusaurMega Venusaur  Grass  Poison     625  ...      123
# 4           4  4             Charmander   Fire     NaN     309  ...       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#    Unnamed: 0  #                       Name Type 1  Type 2  Total1  ...  \
# 5           5  5                 Charmeleon   Fire     NaN     405  ...
# 6           6  6                  Charizard   Fire  Flying     534  ...
# 7           7  6  CharizardMega Charizard X   Fire  Dragon     634  ...
# 8           8  6  CharizardMega Charizard Y   Fire  Flying     634  ...
# 9           9  7                   Squirtle  Water     NaN     314  ...
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 5       58       80       65     80           1      False
# 6       78      109       85    100           1      False
# 7      111      130       85    100           1      False
# 8       78      159      115    100           1      False
# 9       65       50       64     43           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #                     Name Type 1  Type 2  Total1  ...  \
# 10          10   8                Wartortle  Water     NaN     405  ...
# 11          11   9                Blastoise  Water     NaN     530  ...
# 12          12   9  BlastoiseMega Blastoise  Water     NaN     630  ...
# 13          13  10                 Caterpie    Bug     NaN     195  ...
# 14          14  11                  Metapod    Bug     NaN     205  ...
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 10       80       65       80     58           1      False
# 11      100       85      105     78           1      False
# 12      120      135      115     78           1      False
# 13       35       20       20     45           1      False
# 14       55       25       25     30           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #                   Name Type 1  Type 2  Total1  ...  \
# 15          15  12             Butterfree    Bug  Flying     395  ...
# 16          16  13                 Weedle    Bug  Poison     195  ...
# 17          17  14                 Kakuna    Bug  Poison     205  ...
# 18          18  15               Beedrill    Bug  Poison     395  ...
# 19          19  15  BeedrillMega Beedrill    Bug  Poison     495  ...
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 15       50       90       80     70           1      False
# 16       30       20       20     50           1      False
# 17       50       25       25     35           1      False
# 18       40       45       80     75           1      False
# 19       40       15       80    145           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #                 Name  Type 1  Type 2  Total1  ...  Defense  \
# 20          20  16               Pidgey  Normal  Flying     251  ...       40
# 21          21  17            Pidgeotto  Normal  Flying     349  ...       55
# 22          22  18              Pidgeot  Normal  Flying     479  ...       75
# 23          23  18  PidgeotMega Pidgeot  Normal  Flying     579  ...       80
# 24          24  19              Rattata  Normal     NaN     253  ...       35
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20       35       35     56           1      False
# 21       50       50     71           1      False
# 22       70       70    101           1      False
# 23      135       80    121           1      False
# 24       25       35     72           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #      Name  Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 25          25  20  Raticate  Normal     NaN     413  ...       60       50
# 26          26  21   Spearow  Normal  Flying     262  ...       30       31
# 27          27  22    Fearow  Normal  Flying     442  ...       65       61
# 28          28  23     Ekans  Poison     NaN     288  ...       44       40
# 29          29  24     Arbok  Poison     NaN     438  ...       69       65
#
#     Sp. Def  Speed  Generation  Legendary
# 25       70     97           1      False
# 26       31     70           1      False
# 27       61    100           1      False
# 28       54     55           1      False
# 29       79     80           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #              Name    Type 1  Type 2  Total1  ...  Defense  \
# 30          30  25           Pikachu  Electric     NaN     320  ...       40
# 31          31  26            Raichu  Electric     NaN     485  ...       55
# 32          32  27         Sandshrew    Ground     NaN     300  ...       85
# 33          33  28         Sandslash    Ground     NaN     450  ...      110
# 34          34  29  Nidoran (Female)    Poison     NaN     275  ...       52
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 30       50       50     90           1      False
# 31       90       80    110           1      False
# 32       20       30     40           1      False
# 33       45       55     65           1      False
# 34       40       40     41           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #            Name  Type 1  Type 2  Total1  ...  Defense  \
# 35          35  30        Nidorina  Poison     NaN     365  ...       67
# 36          36  31       Nidoqueen  Poison  Ground     505  ...       87
# 37          37  32  Nidoran (Male)  Poison     NaN     273  ...       40
# 38          38  33        Nidorino  Poison     NaN     365  ...       57
# 39          39  34        Nidoking  Poison  Ground     505  ...       77
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 35       55       55     56           1      False
# 36       75       85     76           1      False
# 37       40       40     50           1      False
# 38       55       55     65           1      False
# 39       85       75     85           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #        Name  Type 1 Type 2  Total1  ...  Defense  Sp. Atk  \
# 40          40  35    Clefairy   Fairy    NaN     323  ...       48       60
# 41          41  36    Clefable   Fairy    NaN     483  ...       73       95
# 42          42  37      Vulpix    Fire    NaN     299  ...       40       50
# 43          43  38   Ninetales    Fire    NaN     505  ...       75       81
# 44          44  39  Jigglypuff  Normal  Fairy     270  ...       20       45
#
#     Sp. Def  Speed  Generation  Legendary
# 40       65     35           1      False
# 41       90     60           1      False
# 42       65     65           1      False
# 43      100    100           1      False
# 44       25     20           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #        Name  Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 45          45  40  Wigglytuff  Normal   Fairy     435  ...       45       85
# 46          46  41       Zubat  Poison  Flying     245  ...       35       30
# 47          47  42      Golbat  Poison  Flying     455  ...       70       65
# 48          48  43      Oddish   Grass  Poison     320  ...       55       75
# 49          49  44       Gloom   Grass  Poison     395  ...       70       85
#
#     Sp. Def  Speed  Generation  Legendary
# 45       50     45           1      False
# 46       40     55           1      False
# 47       75     90           1      False
# 48       65     30           1      False
# 49       75     40           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #       Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 50          50  45  Vileplume  Grass  Poison     490  ...       85      110
# 51          51  46      Paras    Bug   Grass     285  ...       55       45
# 52          52  47   Parasect    Bug   Grass     405  ...       80       60
# 53          53  48    Venonat    Bug  Poison     305  ...       50       40
# 54          54  49   Venomoth    Bug  Poison     450  ...       60       90
#
#     Sp. Def  Speed  Generation  Legendary
# 50       90     50           1      False
# 51       55     25           1      False
# 52       80     30           1      False
# 53       55     45           1      False
# 54       75     90           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #     Name  Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 55          55  50  Diglett  Ground     NaN     265  ...       25       35
# 56          56  51  Dugtrio  Ground     NaN     405  ...       50       50
# 57          57  52   Meowth  Normal     NaN     290  ...       35       40
# 58          58  53  Persian  Normal     NaN     440  ...       60       65
# 59          59  54  Psyduck   Water     NaN     320  ...       48       65
#
#     Sp. Def  Speed  Generation  Legendary
# 55       45     95           1      False
# 56       70    120           1      False
# 57       40     90           1      False
# 58       65    115           1      False
# 59       50     55           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #       Name    Type 1  Type 2  Total1  ...  Defense  \
# 60          60  55    Golduck     Water     NaN     500  ...       78
# 61          61  56     Mankey  Fighting     NaN     305  ...       35
# 62          62  57   Primeape  Fighting     NaN     455  ...       60
# 63          63  58  Growlithe      Fire     NaN     350  ...       45
# 64          64  59   Arcanine      Fire     NaN     555  ...       80
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 60       95       80     85           1      False
# 61       35       45     70           1      False
# 62       60       70     95           1      False
# 63       70       50     60           1      False
# 64      100       80     95           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #       Name   Type 1    Type 2  Total1  ...  Defense  \
# 65          65  60    Poliwag    Water       NaN     300  ...       40
# 66          66  61  Poliwhirl    Water       NaN     385  ...       65
# 67          67  62  Poliwrath    Water  Fighting     510  ...       95
# 68          68  63       Abra  Psychic       NaN     310  ...       15
# 69          69  64    Kadabra  Psychic       NaN     400  ...       30
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 65       40       40     90           1      False
# 66       50       50     90           1      False
# 67       70       90     70           1      False
# 68      105       55     90           1      False
# 69      120       70    105           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #                   Name    Type 1  Type 2  Total1  ...  \
# 70          70  65               Alakazam   Psychic     NaN     500  ...
# 71          71  65  AlakazamMega Alakazam   Psychic     NaN     590  ...
# 72          72  66                 Machop  Fighting     NaN     305  ...
# 73          73  67                Machoke  Fighting     NaN     405  ...
# 74          74  68                Machamp  Fighting     NaN     505  ...
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 70       45      135       95    120           1      False
# 71       65      175       95    150           1      False
# 72       50       35       35     35           1      False
# 73       70       50       60     45           1      False
# 74       80       65       85     55           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #        Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 75          75  69  Bellsprout  Grass  Poison     300  ...       35       70
# 76          76  70  Weepinbell  Grass  Poison     390  ...       50       85
# 77          77  71  Victreebel  Grass  Poison     490  ...       65      100
# 78          78  72   Tentacool  Water  Poison     335  ...       35       50
# 79          79  73  Tentacruel  Water  Poison     515  ...       65       80
#
#     Sp. Def  Speed  Generation  Legendary
# 75       30     40           1      False
# 76       45     55           1      False
# 77       70     70           1      False
# 78      100     70           1      False
# 79      120    100           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #      Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 80          80  74   Geodude   Rock  Ground     300  ...      100       30
# 81          81  75  Graveler   Rock  Ground     390  ...      115       45
# 82          82  76     Golem   Rock  Ground     495  ...      130       55
# 83          83  77    Ponyta   Fire     NaN     410  ...       55       65
# 84          84  78  Rapidash   Fire     NaN     500  ...       70       80
#
#     Sp. Def  Speed  Generation  Legendary
# 80       30     20           1      False
# 81       45     35           1      False
# 82       65     45           1      False
# 83       65     90           1      False
# 84       80    105           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #                 Name    Type 1   Type 2  Total1  ...  \
# 85          85  79             Slowpoke     Water  Psychic     315  ...
# 86          86  80              Slowbro     Water  Psychic     490  ...
# 87          87  80  SlowbroMega Slowbro     Water  Psychic     590  ...
# 88          88  81            Magnemite  Electric    Steel     325  ...
# 89          89  82             Magneton  Electric    Steel     465  ...
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 85       65       40       40     15           1      False
# 86      110      100       80     30           1      False
# 87      180      130       80     30           1      False
# 88       70       95       55     45           1      False
# 89       95      120       70     70           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #        Name  Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 90          90  83  Farfetch'd  Normal  Flying     352  ...       55       58
# 91          91  84       Doduo  Normal  Flying     310  ...       45       35
# 92          92  85      Dodrio  Normal  Flying     460  ...       70       60
# 93          93  86        Seel   Water     NaN     325  ...       55       45
# 94          94  87     Dewgong   Water     Ice     475  ...       80       70
#
#     Sp. Def  Speed  Generation  Legendary
# 90       62     60           1      False
# 91       35     75           1      False
# 92       60    100           1      False
# 93       70     45           1      False
# 94       95     70           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#     Unnamed: 0   #      Name  Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 95          95  88    Grimer  Poison     NaN     325  ...       50       40
# 96          96  89       Muk  Poison     NaN     500  ...       75       65
# 97          97  90  Shellder   Water     NaN     305  ...      100       45
# 98          98  91  Cloyster   Water     Ice     525  ...      180       85
# 99          99  92    Gastly   Ghost  Poison     310  ...       30      100
#
#     Sp. Def  Speed  Generation  Legendary
# 95       50     25           1      False
# 96      100     50           1      False
# 97       25     40           1      False
# 98       45     70           1      False
# 99       35     80           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0   #               Name   Type 1  Type 2  Total1  ...  Defense  \
# 100         100  93            Haunter    Ghost  Poison     405  ...       45
# 101         101  94             Gengar    Ghost  Poison     500  ...       60
# 102         102  94  GengarMega Gengar    Ghost  Poison     600  ...       80
# 103         103  95               Onix     Rock  Ground     385  ...      160
# 104         104  96            Drowzee  Psychic     NaN     328  ...       45
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 100      115       55     95           1      False
# 101      130       75    110           1      False
# 102      170       95    130           1      False
# 103       30       45     70           1      False
# 104       43       90     42           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name    Type 1  Type 2  Total1  ...  Defense  \
# 105         105   97      Hypno   Psychic     NaN     483  ...       70
# 106         106   98     Krabby     Water     NaN     325  ...       90
# 107         107   99    Kingler     Water     NaN     475  ...      115
# 108         108  100    Voltorb  Electric     NaN     330  ...       50
# 109         109  101  Electrode  Electric     NaN     480  ...       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 105       73      115     67           1      False
# 106       25       25     50           1      False
# 107       50       50     75           1      False
# 108       55       55    100           1      False
# 109       80       80    140           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name    Type 1   Type 2  Total1  ...  Defense  \
# 110         110  102  Exeggcute     Grass  Psychic     325  ...       80
# 111         111  103  Exeggutor     Grass  Psychic     520  ...       85
# 112         112  104     Cubone    Ground      NaN     320  ...       95
# 113         113  105    Marowak    Ground      NaN     425  ...      110
# 114         114  106  Hitmonlee  Fighting      NaN     455  ...       53
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 110       60       45     40           1      False
# 111      125       65     55           1      False
# 112       40       50     35           1      False
# 113       50       80     45           1      False
# 114       35      110     87           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #        Name    Type 1 Type 2  Total1  ...  Defense  \
# 115         115  107  Hitmonchan  Fighting    NaN     455  ...       79
# 116         116  108   Lickitung    Normal    NaN     385  ...       75
# 117         117  109     Koffing    Poison    NaN     340  ...       95
# 118         118  110     Weezing    Poison    NaN     490  ...      120
# 119         119  111     Rhyhorn    Ground   Rock     345  ...       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 115       35      110     76           1      False
# 116       60       75     30           1      False
# 117       60       45     35           1      False
# 118       85       70     60           1      False
# 119       30       30     25           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                       Name  Type 1 Type 2  Total1  ...  \
# 120         120  112                     Rhydon  Ground   Rock     485  ...
# 121         121  113                    Chansey  Normal    NaN     450  ...
# 122         122  114                    Tangela   Grass    NaN     435  ...
# 123         123  115                 Kangaskhan  Normal    NaN     490  ...
# 124         124  115  KangaskhanMega Kangaskhan  Normal    NaN     590  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 120      120       45       45     40           1      False
# 121        5       35      105     50           1      False
# 122      115      100       40     60           1      False
# 123       80       40       80     90           1      False
# 124      100       60      100    100           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #     Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 125         125  116   Horsea  Water     NaN     295  ...       70       70
# 126         126  117   Seadra  Water     NaN     440  ...       95       95
# 127         127  118  Goldeen  Water     NaN     320  ...       60       35
# 128         128  119  Seaking  Water     NaN     450  ...       65       65
# 129         129  120   Staryu  Water     NaN     340  ...       55       70
#
#      Sp. Def  Speed  Generation  Legendary
# 125       25     60           1      False
# 126       45     85           1      False
# 127       50     63           1      False
# 128       80     68           1      False
# 129       55     85           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #        Name    Type 1   Type 2  Total1  ...  Defense  \
# 130         130  121     Starmie     Water  Psychic     520  ...       85
# 131         131  122    Mr. Mime   Psychic    Fairy     460  ...       65
# 132         132  123     Scyther       Bug   Flying     500  ...       80
# 133         133  124        Jynx       Ice  Psychic     455  ...       35
# 134         134  125  Electabuzz  Electric      NaN     490  ...       57
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 130      100       85    115           1      False
# 131      100      120     90           1      False
# 132       55       80    105           1      False
# 133      115       95     95           1      False
# 134       95       85    105           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #               Name  Type 1  Type 2  Total1  ...  Defense  \
# 135         135  126             Magmar    Fire     NaN     495  ...       57
# 136         136  127             Pinsir     Bug     NaN     500  ...      100
# 137         137  127  PinsirMega Pinsir     Bug  Flying     600  ...      120
# 138         138  128             Tauros  Normal     NaN     490  ...       95
# 139         139  129           Magikarp   Water     NaN     200  ...       55
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 135      100       85     93           1      False
# 136       55       70     85           1      False
# 137       65       90    105           1      False
# 138       40       70    110           1      False
# 139       15       20     80           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                   Name  Type 1  Type 2  Total1  ...  \
# 140         140  130               Gyarados   Water  Flying     540  ...
# 141         141  130  GyaradosMega Gyarados   Water    Dark     640  ...
# 142         142  131                 Lapras   Water     Ice     535  ...
# 143         143  132                  Ditto  Normal     NaN     288  ...
# 144         144  133                  Eevee  Normal     NaN     325  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 140       79       60      100     81           1      False
# 141      109       70      130     81           1      False
# 142       80       85       95     60           1      False
# 143       48       48       48     48           1      False
# 144       50       45       65     55           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name    Type 1 Type 2  Total1  ...  Defense  \
# 145         145  134  Vaporeon     Water    NaN     525  ...       60
# 146         146  135   Jolteon  Electric    NaN     525  ...       60
# 147         147  136   Flareon      Fire    NaN     525  ...       60
# 148         148  137   Porygon    Normal    NaN     395  ...       70
# 149         149  138   Omanyte      Rock  Water     355  ...      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 145      110       95     65           1      False
# 146      110       95    130           1      False
# 147       95      110     65           1      False
# 148       85       75     40           1      False
# 149       90       55     35           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                       Name Type 1  Type 2  Total1  ...  \
# 150         150  139                    Omastar   Rock   Water     495  ...
# 151         151  140                     Kabuto   Rock   Water     355  ...
# 152         152  141                   Kabutops   Rock   Water     495  ...
# 153         153  142                 Aerodactyl   Rock  Flying     515  ...
# 154         154  142  AerodactylMega Aerodactyl   Rock  Flying     615  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 150      125      115       70     55           1      False
# 151       90       55       45     55           1      False
# 152      105       65       70     80           1      False
# 153       65       60       75    130           1      False
# 154       85       70       95    150           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name    Type 1  Type 2  Total1  ...  Defense  \
# 155         155  143   Snorlax    Normal     NaN     540  ...       65
# 156         156  144  Articuno       Ice  Flying     580  ...      100
# 157         157  145    Zapdos  Electric  Flying     580  ...       85
# 158         158  146   Moltres      Fire  Flying     580  ...       90
# 159         159  147   Dratini    Dragon     NaN     300  ...       45
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 155       65      110     30           1      False
# 156       95      125     85           1       True
# 157      125       90    100           1       True
# 158      125       85     90           1       True
# 159       50       50     50           1      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                 Name   Type 1    Type 2  Total1  ...  \
# 160         160  148            Dragonair   Dragon       NaN     420  ...
# 161         161  149            Dragonite   Dragon    Flying     600  ...
# 162         162  150               Mewtwo  Psychic       NaN     680  ...
# 163         163  150  MewtwoMega Mewtwo X  Psychic  Fighting     780  ...
# 164         164  150  MewtwoMega Mewtwo Y  Psychic       NaN     780  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 160       65       70       70     70           1      False
# 161       95      100      100     80           1      False
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True
# 164       70      194      120    140           1       True
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name   Type 1  Type 2  Total1  ...  Defense  \
# 165         165  151        Mew  Psychic     NaN     600  ...      100
# 166         166  152  Chikorita    Grass     NaN     318  ...       65
# 167         167  153    Bayleef    Grass     NaN     405  ...       80
# 168         168  154   Meganium    Grass     NaN     525  ...      100
# 169         169  155  Cyndaquil     Fire     NaN     309  ...       43
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 165      100      100    100           1      False
# 166       49       65     45           2      False
# 167       63       80     60           2      False
# 168       83      100     80           2      False
# 169       60       50     65           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #        Name Type 1  Type 2  Total1  ...  Defense  \
# 170         170  156     Quilava   Fire     NaN     405  ...       58
# 171         171  157  Typhlosion   Fire     NaN     534  ...       78
# 172         172  158    Totodile  Water     NaN     314  ...       64
# 173         173  159    Croconaw  Water     NaN     405  ...       80
# 174         174  160  Feraligatr  Water     NaN     530  ...      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 170       80       65     80           2      False
# 171      109       85    100           2      False
# 172       44       48     43           2      False
# 173       59       63     58           2      False
# 174       79       83     78           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name  Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 175         175  161   Sentret  Normal     NaN     215  ...       34       35
# 176         176  162    Furret  Normal     NaN     415  ...       64       45
# 177         177  163  Hoothoot  Normal  Flying     262  ...       30       36
# 178         178  164   Noctowl  Normal  Flying     442  ...       50       76
# 179         179  165    Ledyba     Bug  Flying     265  ...       30       40
#
#      Sp. Def  Speed  Generation  Legendary
# 175       45     20           2      False
# 176       55     90           2      False
# 177       56     50           2      False
# 178       96     70           2      False
# 179       80     55           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name  Type 1    Type 2  Total1  ...  Defense  \
# 180         180  166    Ledian     Bug    Flying     390  ...       50
# 181         181  167  Spinarak     Bug    Poison     250  ...       40
# 182         182  168   Ariados     Bug    Poison     390  ...       70
# 183         183  169    Crobat  Poison    Flying     535  ...       80
# 184         184  170  Chinchou   Water  Electric     330  ...       38
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 180       55      110     85           2      False
# 181       40       40     30           2      False
# 182       60       60     40           2      False
# 183       70       80    130           2      False
# 184       56       56     67           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name    Type 1    Type 2  Total1  ...  Defense  \
# 185         185  171    Lanturn     Water  Electric     460  ...       58
# 186         186  172      Pichu  Electric       NaN     205  ...       15
# 187         187  173     Cleffa     Fairy       NaN     218  ...       28
# 188         188  174  Igglybuff    Normal     Fairy     210  ...       15
# 189         189  175     Togepi     Fairy       NaN     245  ...       65
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 185       76       76     67           2      False
# 186       35       35     60           2      False
# 187       45       55     15           2      False
# 188       40       20     15           2      False
# 189       40       65     20           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #     Name    Type 1  Type 2  Total1  ...  Defense  \
# 190         190  176  Togetic     Fairy  Flying     405  ...       85
# 191         191  177     Natu   Psychic  Flying     320  ...       45
# 192         192  178     Xatu   Psychic  Flying     470  ...       70
# 193         193  179   Mareep  Electric     NaN     280  ...       40
# 194         194  180  Flaaffy  Electric     NaN     365  ...       55
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 190       80      105     40           2      False
# 191       70       45     70           2      False
# 192       95       70     95           2      False
# 193       65       45     35           2      False
# 194       80       60     45           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                   Name    Type 1  Type 2  Total1  ...  \
# 195         195  181               Ampharos  Electric     NaN     510  ...
# 196         196  181  AmpharosMega Ampharos  Electric  Dragon     610  ...
# 197         197  182              Bellossom     Grass     NaN     490  ...
# 198         198  183                 Marill     Water   Fairy     250  ...
# 199         199  184              Azumarill     Water   Fairy     420  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 195       85      115       90     55           2      False
# 196      105      165      110     45           2      False
# 197       95       90      100     50           2      False
# 198       50       20       50     40           2      False
# 199       80       60       80     50           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 200         200  185  Sudowoodo   Rock     NaN     410  ...      115       30
# 201         201  186   Politoed  Water     NaN     500  ...       75       90
# 202         202  187     Hoppip  Grass  Flying     250  ...       40       35
# 203         203  188   Skiploom  Grass  Flying     340  ...       50       45
# 204         204  189   Jumpluff  Grass  Flying     460  ...       70       55
#
#      Sp. Def  Speed  Generation  Legendary
# 200       65     30           2      False
# 201      100     70           2      False
# 202       55     50           2      False
# 203       65     80           2      False
# 204       95    110           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name  Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 205         205  190     Aipom  Normal     NaN     360  ...       55       40
# 206         206  191   Sunkern   Grass     NaN     180  ...       30       30
# 207         207  192  Sunflora   Grass     NaN     425  ...       55      105
# 208         208  193     Yanma     Bug  Flying     390  ...       45       75
# 209         209  194    Wooper   Water  Ground     210  ...       45       25
#
#      Sp. Def  Speed  Generation  Legendary
# 205       55     85           2      False
# 206       30     30           2      False
# 207       85     30           2      False
# 208       45     95           2      False
# 209       25     15           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name   Type 1   Type 2  Total1  ...  Defense  \
# 210         210  195  Quagsire    Water   Ground     430  ...       85
# 211         211  196    Espeon  Psychic      NaN     525  ...       60
# 212         212  197   Umbreon     Dark      NaN     525  ...      110
# 213         213  198   Murkrow     Dark   Flying     405  ...       42
# 214         214  199  Slowking    Water  Psychic     490  ...       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 210       65       65     35           2      False
# 211      130       95    110           2      False
# 212       60      130     65           2      False
# 213       85       42     91           2      False
# 214      100      110     30           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #        Name   Type 1   Type 2  Total1  ...  Defense  \
# 215         215  200  Misdreavus    Ghost      NaN     435  ...       60
# 216         216  201       Unown  Psychic      NaN     336  ...       48
# 217         217  202   Wobbuffet  Psychic      NaN     405  ...       58
# 218         218  203   Girafarig   Normal  Psychic     455  ...       65
# 219         219  204      Pineco      Bug      NaN     290  ...       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 215       85       85     85           2      False
# 216       72       48     48           2      False
# 217       33       58     33           2      False
# 218       90       65     85           2      False
# 219       35       35     15           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                 Name  Type 1  Type 2  Total1  ...  \
# 220         220  205           Forretress     Bug   Steel     465  ...
# 221         221  206            Dunsparce  Normal     NaN     415  ...
# 222         222  207               Gligar  Ground  Flying     430  ...
# 223         223  208              Steelix   Steel  Ground     510  ...
# 224         224  208  SteelixMega Steelix   Steel  Ground     610  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 220      140       60       60     40           2      False
# 221       70       65       65     45           2      False
# 222      105       35       65     85           2      False
# 223      200       55       65     30           2      False
# 224      230       55       95     30           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #               Name Type 1  Type 2  Total1  ...  Defense  \
# 225         225  209           Snubbull  Fairy     NaN     300  ...       50
# 226         226  210           Granbull  Fairy     NaN     450  ...       75
# 227         227  211           Qwilfish  Water  Poison     430  ...       75
# 228         228  212             Scizor    Bug   Steel     500  ...      100
# 229         229  212  ScizorMega Scizor    Bug   Steel     600  ...      140
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 225       40       40     30           2      False
# 226       60       60     45           2      False
# 227       55       55     85           2      False
# 228       55       80     65           2      False
# 229       65      100     75           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                     Name  Type 1    Type 2  Total1  ...  \
# 230         230  213                  Shuckle     Bug      Rock     505  ...
# 231         231  214                Heracross     Bug  Fighting     500  ...
# 232         232  214  HeracrossMega Heracross     Bug  Fighting     600  ...
# 233         233  215                  Sneasel    Dark       Ice     430  ...
# 234         234  216                Teddiursa  Normal       NaN     330  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 230      230       10      230      5           2      False
# 231       75       40       95     85           2      False
# 232      115       40      105     75           2      False
# 233       55       35       75    115           2      False
# 234       50       50       50     40           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name  Type 1  Type 2  Total1  ...  Defense  \
# 235         235  217   Ursaring  Normal     NaN     500  ...       75
# 236         236  218     Slugma    Fire     NaN     250  ...       40
# 237         237  219   Magcargo    Fire    Rock     410  ...      120
# 238         238  220     Swinub     Ice  Ground     250  ...       40
# 239         239  221  Piloswine     Ice  Ground     450  ...       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 235       75       75     55           2      False
# 236       70       40     20           2      False
# 237       80       80     30           2      False
# 238       30       30     50           2      False
# 239       60       60     50           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 240         240  222    Corsola  Water    Rock     380  ...       85       65
# 241         241  223   Remoraid  Water     NaN     300  ...       35       65
# 242         242  224  Octillery  Water     NaN     480  ...       75      105
# 243         243  225   Delibird    Ice  Flying     330  ...       45       65
# 244         244  226    Mantine  Water  Flying     465  ...       70       80
#
#      Sp. Def  Speed  Generation  Legendary
# 240       85     35           2      False
# 241       35     65           2      False
# 242       75     45           2      False
# 243       45     75           2      False
# 244      140     70           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                   Name Type 1  Type 2  Total1  ...  \
# 245         245  227               Skarmory  Steel  Flying     465  ...
# 246         246  228               Houndour   Dark    Fire     330  ...
# 247         247  229               Houndoom   Dark    Fire     500  ...
# 248         248  229  HoundoomMega Houndoom   Dark    Fire     600  ...
# 249         249  230                Kingdra  Water  Dragon     540  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 245      140       40       70     70           2      False
# 246       30       80       50     65           2      False
# 247       50      110       80     95           2      False
# 248       90      140       90    115           2      False
# 249       95       95       95     85           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name  Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 250         250  231    Phanpy  Ground     NaN     330  ...       60       40
# 251         251  232   Donphan  Ground     NaN     500  ...      120       60
# 252         252  233  Porygon2  Normal     NaN     515  ...       90      105
# 253         253  234  Stantler  Normal     NaN     465  ...       62       85
# 254         254  235  Smeargle  Normal     NaN     250  ...       35       20
#
#      Sp. Def  Speed  Generation  Legendary
# 250       40     40           2      False
# 251       60     50           2      False
# 252       95     60           2      False
# 253       65     85           2      False
# 254       45     75           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name    Type 1   Type 2  Total1  ...  Defense  \
# 255         255  236    Tyrogue  Fighting      NaN     210  ...       35
# 256         256  237  Hitmontop  Fighting      NaN     455  ...       95
# 257         257  238   Smoochum       Ice  Psychic     305  ...       15
# 258         258  239     Elekid  Electric      NaN     360  ...       37
# 259         259  240      Magby      Fire      NaN     365  ...       37
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 255       35       35     35           2      False
# 256       35      110     70           2      False
# 257       85       65     65           2      False
# 258       65       55     95           2      False
# 259       70       55     83           2      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #     Name    Type 1  Type 2  Total1  ...  Defense  \
# 260         260  241  Miltank    Normal     NaN     490  ...      105
# 261         261  242  Blissey    Normal     NaN     540  ...       10
# 262         262  243   Raikou  Electric     NaN     580  ...       75
# 263         263  244    Entei      Fire     NaN     580  ...       85
# 264         264  245  Suicune     Water     NaN     580  ...      115
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 260       40       70    100           2      False
# 261       75      135     55           2      False
# 262      115      100    115           2       True
# 263       90       75    100           2       True
# 264       90      115     85           2       True
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                     Name   Type 1  Type 2  Total1  ...  \
# 265         265  246                 Larvitar     Rock  Ground     300  ...
# 266         266  247                  Pupitar     Rock  Ground     410  ...
# 267         267  248                Tyranitar     Rock    Dark     600  ...
# 268         268  248  TyranitarMega Tyranitar     Rock    Dark     700  ...
# 269         269  249                    Lugia  Psychic  Flying     680  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 265       50       45       50     41           2      False
# 266       70       65       70     51           2      False
# 267      110       95      100     61           2      False
# 268      150       95      120     71           2      False
# 269      130       90      154    110           2       True
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name   Type 1  Type 2  Total1  ...  Defense  \
# 270         270  250     Ho-oh     Fire  Flying     680  ...       90
# 271         271  251    Celebi  Psychic   Grass     600  ...      100
# 272         272  252   Treecko    Grass     NaN     310  ...       35
# 273         273  253   Grovyle    Grass     NaN     405  ...       45
# 274         274  254  Sceptile    Grass     NaN     530  ...       65
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 270      110      154     90           2       True
# 271      100      100    100           2      False
# 272       65       55     70           3      False
# 273       85       65     95           3      False
# 274      105       85    120           3      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                   Name Type 1    Type 2  Total1  ...  \
# 275         275  254  SceptileMega Sceptile  Grass    Dragon     630  ...
# 276         276  255                Torchic   Fire       NaN     310  ...
# 277         277  256              Combusken   Fire  Fighting     405  ...
# 278         278  257               Blaziken   Fire  Fighting     530  ...
# 279         279  257  BlazikenMega Blaziken   Fire  Fighting     630  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 275       75      145       85    145           3      False
# 276       40       70       50     45           3      False
# 277       60       85       60     55           3      False
# 278       70      110       70     80           3      False
# 279       80      130       80    100           3      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                   Name Type 1  Type 2  Total1  ...  \
# 280         280  258                 Mudkip  Water     NaN     310  ...
# 281         281  259              Marshtomp  Water  Ground     405  ...
# 282         282  260               Swampert  Water  Ground     535  ...
# 283         283  260  SwampertMega Swampert  Water  Ground     635  ...
# 284         284  261              Poochyena   Dark     NaN     220  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 280       50       50       50     40           3      False
# 281       70       60       70     50           3      False
# 282       90       85       90     60           3      False
# 283      110       95      110     70           3      False
# 284       35       30       30     35           3      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name  Type 1  Type 2  Total1  ...  Defense  \
# 285         285  262  Mightyena    Dark     NaN     420  ...       70
# 286         286  263  Zigzagoon  Normal     NaN     240  ...       41
# 287         287  264    Linoone  Normal     NaN     420  ...       61
# 288         288  265    Wurmple     Bug     NaN     195  ...       35
# 289         289  266    Silcoon     Bug     NaN     205  ...       55
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 285       60       60     70           3      False
# 286       30       41     60           3      False
# 287       50       61    100           3      False
# 288       20       30     20           3      False
# 289       25       25     15           3      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 290         290  267  Beautifly    Bug  Flying     395  ...       50      100
# 291         291  268    Cascoon    Bug     NaN     205  ...       55       25
# 292         292  269     Dustox    Bug  Poison     385  ...       70       50
# 293         293  270      Lotad  Water   Grass     220  ...       30       40
# 294         294  271     Lombre  Water   Grass     340  ...       50       60
#
#      Sp. Def  Speed  Generation  Legendary
# ...
# 702  ...       70      125       80    111           5       True
# 703  ...       80      110       90    121           5       True
# 704  ...       70      125       80    111           5       True
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                     Name    Type 1    Type 2  Total1  \
# 705         705  642   ThundurusTherian Forme  Electric    Flying     580
# 706         706  643                 Reshiram    Dragon      Fire     680
# 707         707  644                   Zekrom    Dragon  Electric     680
# 708         708  645  LandorusIncarnate Forme    Ground    Flying     600
# 709         709  645    LandorusTherian Forme    Ground    Flying     600
#
#      ...  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 705  ...       70      145       80    101           5       True
# 706  ...      100      150      120     90           5       True
# 707  ...      120      120      100     90           5       True
# 708  ...       90      115       80    101           5       True
# 709  ...       90      105       80     91           5       True
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                  Name  Type 1    Type 2  Total1  ...  \
# 710         710  646                Kyurem  Dragon       Ice     660  ...
# 711         711  646    KyuremBlack Kyurem  Dragon       Ice     700  ...
# 712         712  646    KyuremWhite Kyurem  Dragon       Ice     700  ...
# 713         713  647  KeldeoOrdinary Forme   Water  Fighting     580  ...
# 714         714  647  KeldeoResolute Forme   Water  Fighting     580  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 710       90      130       90     95           5       True
# 711      100      120       90     95           5       True
# 712       90      170      100     95           5       True
# 713       90      129       90    108           5      False
# 714       90      129       90    108           5      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                     Name  Type 1    Type 2  Total1  ...  \
# 715         715  648       MeloettaAria Forme  Normal   Psychic     600  ...
# 716         716  648  MeloettaPirouette Forme  Normal  Fighting     600  ...
# 717         717  649                 Genesect     Bug     Steel     600  ...
# 718         718  650                  Chespin   Grass       NaN     313  ...
# 719         719  651                Quilladin   Grass       NaN     405  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 715       77      128      128     90           5      False
# 716       90       77       77    128           5      False
# 717       95      120       95     99           5      False
# 718       65       48       45     38           6      False
# 719       95       56       58     57           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #        Name Type 1    Type 2  Total1  ...  Defense  \
# 720         720  652  Chesnaught  Grass  Fighting     530  ...      122
# 721         721  653    Fennekin   Fire       NaN     307  ...       40
# 722         722  654     Braixen   Fire       NaN     409  ...       58
# 723         723  655     Delphox   Fire   Psychic     534  ...       72
# 724         724  656     Froakie  Water       NaN     314  ...       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 720       74       75     64           6      False
# 721       62       60     60           6      False
# 722       90       70     73           6      False
# 723      114      100    104           6      False
# 724       62       44     71           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #        Name  Type 1  Type 2  Total1  ...  Defense  \
# 725         725  657   Frogadier   Water     NaN     405  ...       52
# 726         726  658    Greninja   Water    Dark     530  ...       67
# 727         727  659    Bunnelby  Normal     NaN     237  ...       38
# 728         728  660   Diggersby  Normal  Ground     423  ...       77
# 729         729  661  Fletchling  Normal  Flying     278  ...       43
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 725       83       56     97           6      False
# 726      103       71    122           6      False
# 727       32       36     57           6      False
# 728       50       77     78           6      False
# 729       40       38     62           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #         Name Type 1  Type 2  Total1  ...  Defense  \
# 730         730  662  Fletchinder   Fire  Flying     382  ...       55
# 731         731  663   Talonflame   Fire  Flying     499  ...       71
# 732         732  664   Scatterbug    Bug     NaN     200  ...       40
# 733         733  665       Spewpa    Bug     NaN     213  ...       60
# 734         734  666     Vivillon    Bug  Flying     411  ...       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 730       56       52     84           6      False
# 731       74       69    126           6      False
# 732       27       25     35           6      False
# 733       27       30     29           6      False
# 734       90       50     89           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #     Name Type 1  Type 2  Total1  ...  Defense  Sp. Atk  \
# 735         735  667   Litleo   Fire  Normal     369  ...       58       73
# 736         736  668   Pyroar   Fire  Normal     507  ...       72      109
# 737         737  669  Flabébé  Fairy     NaN     303  ...       39       61
# 738         738  670  Floette  Fairy     NaN     371  ...       47       75
# 739         739  671  Florges  Fairy     NaN     552  ...       68      112
#
#      Sp. Def  Speed  Generation  Legendary
# 735       54     72           6      False
# 736       66    106           6      False
# 737       79     42           6      False
# 738       98     52           6      False
# 739      154     75           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #     Name    Type 1 Type 2  Total1  ...  Defense  Sp. Atk  \
# 740         740  672   Skiddo     Grass    NaN     350  ...       48       62
# 741         741  673   Gogoat     Grass    NaN     531  ...       62       97
# 742         742  674  Pancham  Fighting    NaN     348  ...       62       46
# 743         743  675  Pangoro  Fighting   Dark     495  ...       78       69
# 744         744  676  Furfrou    Normal    NaN     472  ...       60       65
#
#      Sp. Def  Speed  Generation  Legendary
# 740       57     52           6      False
# 741       81     68           6      False
# 742       48     43           6      False
# 743       71     58           6      False
# 744       90    102           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #            Name   Type 1 Type 2  Total1  ...  Defense  \
# 745         745  677          Espurr  Psychic    NaN     355  ...       54
# 746         746  678    MeowsticMale  Psychic    NaN     466  ...       76
# 747         747  678  MeowsticFemale  Psychic    NaN     466  ...       76
# 748         748  679         Honedge    Steel  Ghost     325  ...      100
# 749         749  680        Doublade    Steel  Ghost     448  ...      150
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 745       63       60     68           6      False
# 746       83       81    104           6      False
# 747       83       81    104           6      False
# 748       35       37     28           6      False
# 749       45       49     35           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                   Name Type 1 Type 2  Total1  ...  \
# 750         750  681   AegislashBlade Forme  Steel  Ghost     520  ...
# 751         751  681  AegislashShield Forme  Steel  Ghost     520  ...
# 752         752  682               Spritzee  Fairy    NaN     341  ...
# 753         753  683             Aromatisse  Fairy    NaN     462  ...
# 754         754  684                Swirlix  Fairy    NaN     341  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 750       50      150       50     60           6      False
# 751      150       50      150     60           6      False
# 752       60       63       65     23           6      False
# 753       72       99       89     29           6      False
# 754       66       59       57     49           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #        Name Type 1   Type 2  Total1  ...  Defense  \
# 755         755  685    Slurpuff  Fairy      NaN     480  ...       86
# 756         756  686       Inkay   Dark  Psychic     288  ...       53
# 757         757  687     Malamar   Dark  Psychic     482  ...       88
# 758         758  688     Binacle   Rock    Water     306  ...       67
# 759         759  689  Barbaracle   Rock    Water     500  ...      115
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 755       85       75     72           6      False
# 756       37       46     45           6      False
# 757       68       75     73           6      False
# 758       39       56     50           6      False
# 759       54       86     68           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #        Name    Type 1  Type 2  Total1  ...  Defense  \
# 760         760  690      Skrelp    Poison   Water     320  ...       60
# 761         761  691    Dragalge    Poison  Dragon     494  ...       90
# 762         762  692   Clauncher     Water     NaN     330  ...       62
# 763         763  693   Clawitzer     Water     NaN     500  ...       88
# 764         764  694  Helioptile  Electric  Normal     289  ...       33
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 760       60       60     30           6      False
# 761       97      123     44           6      False
# 762       58       63     44           6      False
# 763      120       89     59           6      False
# 764       61       43     70           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name    Type 1  Type 2  Total1  ...  Defense  \
# 765         765  695  Heliolisk  Electric  Normal     481  ...       52
# 766         766  696     Tyrunt      Rock  Dragon     362  ...       77
# 767         767  697  Tyrantrum      Rock  Dragon     521  ...      119
# 768         768  698     Amaura      Rock     Ice     362  ...       50
# 769         769  699    Aurorus      Rock     Ice     521  ...       72
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 765      109       94    109           6      False
# 766       45       45     48           6      False
# 767       69       59     71           6      False
# 768       67       63     46           6      False
# 769       99       92     58           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #      Name    Type 1  Type 2  Total1  ...  Defense  \
# 770         770  700   Sylveon     Fairy     NaN     525  ...       65
# 771         771  701  Hawlucha  Fighting  Flying     500  ...       75
# 772         772  702   Dedenne  Electric   Fairy     431  ...       57
# 773         773  703   Carbink      Rock   Fairy     500  ...      150
# 774         774  704     Goomy    Dragon     NaN     300  ...       35
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 770      110      130     60           6      False
# 771       74       63    118           6      False
# 772       81       67    101           6      False
# 773       50      150     50           6      False
# 774       55       75     40           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #       Name  Type 1 Type 2  Total1  ...  Defense  Sp. Atk  \
# 775         775  705    Sliggoo  Dragon    NaN     452  ...       53       83
# 776         776  706     Goodra  Dragon    NaN     600  ...       70      110
# 777         777  707     Klefki   Steel  Fairy     470  ...       91       80
# 778         778  708   Phantump   Ghost  Grass     309  ...       48       50
# 779         779  709  Trevenant   Ghost  Grass     474  ...       76       65
#
#      Sp. Def  Speed  Generation  Legendary
# 775      113     60           6      False
# 776      150     80           6      False
# 777       87     75           6      False
# 778       60     38           6      False
# 779       82     56           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                   Name Type 1 Type 2  Total1  ...  \
# 780         780  710  PumpkabooAverage Size  Ghost  Grass     335  ...
# 781         781  710    PumpkabooSmall Size  Ghost  Grass     335  ...
# 782         782  710    PumpkabooLarge Size  Ghost  Grass     335  ...
# 783         783  710    PumpkabooSuper Size  Ghost  Grass     335  ...
# 784         784  711  GourgeistAverage Size  Ghost  Grass     494  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 780       70       44       55     51           6      False
# 781       70       44       55     56           6      False
# 782       70       44       55     46           6      False
# 783       70       44       55     41           6      False
# 784      122       58       75     84           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                 Name Type 1 Type 2  Total1  ...  Defense  \
# 785         785  711  GourgeistSmall Size  Ghost  Grass     494  ...      122
# 786         786  711  GourgeistLarge Size  Ghost  Grass     494  ...      122
# 787         787  711  GourgeistSuper Size  Ghost  Grass     494  ...      122
# 788         788  712             Bergmite    Ice    NaN     304  ...       85
# 789         789  713              Avalugg    Ice    NaN     514  ...      184
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 785       58       75     99           6      False
# 786       58       75     69           6      False
# 787       58       75     54           6      False
# 788       32       35     28           6      False
# 789       44       46     28           6      False
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #              Name  Type 1  Type 2  Total1  ...  Defense  \
# 790         790  714            Noibat  Flying  Dragon     245  ...       35
# 791         791  715           Noivern  Flying  Dragon     535  ...       80
# 792         792  716           Xerneas   Fairy     NaN     680  ...       95
# 793         793  717           Yveltal    Dark  Flying     680  ...       95
# 794         794  718  Zygarde50% Forme  Dragon  Ground     600  ...      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# 791       97       80    123           6      False
# 792      131       98     99           6       True
# 793      131       98     99           6       True
# 794       81       95     95           6       True
#
# [5 rows x 14 columns]
# Chunk DF
#      Unnamed: 0    #                 Name   Type 1 Type 2  Total1  ...  \
# 795         795  719              Diancie     Rock  Fairy     600  ...
# 796         796  719  DiancieMega Diancie     Rock  Fairy     700  ...
# 797         797  720  HoopaHoopa Confined  Psychic  Ghost     600  ...
# 798         798  720   HoopaHoopa Unbound  Psychic   Dark     680  ...
# 799         799  721            Volcanion     Fire  Water     600  ...
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [5 rows x 14 columns]

# %%
#Cleaning data
import pandas as pd
import numpy as np

people={
    'first':['Ankita','Akshat','Mohammed','Pranav', np.nan, None, 'NA'],
    'last':['Pradhan','Bajaj', 'Saleh', 'Muketjee',np.nan,np.nan,'Missing'],
    'email':['ankitapradgan@gmail.com','akshatbajaj@gmail.com','mohdsaleg@gmail.com',None,np.nan,'anonymous@gmail.com','NA'],
    'age':['33','35','40','63',None,None,'Missing']
}
df=pd.DataFrame(people)
df
# Out:
#       first      last                    email      age
# 0    Ankita   Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat     Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed     Saleh      mohdsaleg@gmail.com       40
# 3    Pranav  Muketjee                     None       63
# 4       NaN       NaN                      NaN     None
# 5      None       NaN      anonymous@gmail.com     None
# 6        NA   Missing                       NA  Missing

# %%
df.dropna()
# Out:
#       first     last                    email      age
# 0    Ankita  Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat    Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed    Saleh      mohdsaleg@gmail.com       40
# 6        NA  Missing                       NA  Missing

# %%
df.dropna(axis='index',how='any')
# Out:
#       first     last                    email      age
# 0    Ankita  Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat    Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed    Saleh      mohdsaleg@gmail.com       40
# 6        NA  Missing                       NA  Missing

# %%
df.dropna(axis='index',how='all')
# Out:
#       first      last                    email      age
# 0    Ankita   Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat     Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed     Saleh      mohdsaleg@gmail.com       40
# 3    Pranav  Muketjee                     None       63
# 5      None       NaN      anonymous@gmail.com     None
# 6        NA   Missing                       NA  Missing

# %%
df.dropna(axis='columns',how='all')
# Out:
#       first      last                    email      age
# 0    Ankita   Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat     Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed     Saleh      mohdsaleg@gmail.com       40
# 3    Pranav  Muketjee                     None       63
# 4       NaN       NaN                      NaN     None
# 5      None       NaN      anonymous@gmail.com     None
# 6        NA   Missing                       NA  Missing

# %%
df.dropna(axis='columns',how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df.dropna(axis='index',how='any',subset=['email'])
# Out:
#       first     last                    email      age
# 0    Ankita  Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat    Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed    Saleh      mohdsaleg@gmail.com       40
# 5      None      NaN      anonymous@gmail.com     None
# 6        NA  Missing                       NA  Missing

# %%
df.dropna(axis='index',how='all',subset=['email'])
# Out:
#       first     last                    email      age
# 0    Ankita  Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat    Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed    Saleh      mohdsaleg@gmail.com       40
# 5      None      NaN      anonymous@gmail.com     None
# 6        NA  Missing                       NA  Missing

# %%
df.dropna(axis='index',how='all',subset=['last','email'])
# Out:
#       first      last                    email      age
# 0    Ankita   Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat     Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed     Saleh      mohdsaleg@gmail.com       40
# 3    Pranav  Muketjee                     None       63
# 5      None       NaN      anonymous@gmail.com     None
# 6        NA   Missing                       NA  Missing

# %%
df=pd.DataFrame(people)
df.replace('NA',np.nan, inplace=True)
df.replace('Missing',np.nan, inplace=True)

# %%
df
# Out:
#       first      last                    email   age
# 0    Ankita   Pradhan  ankitapradgan@gmail.com    33
# 1    Akshat     Bajaj    akshatbajaj@gmail.com    35
# 2  Mohammed     Saleh      mohdsaleg@gmail.com    40
# 3    Pranav  Muketjee                     None    63
# 4       NaN       NaN                      NaN  None
# 5      None       NaN      anonymous@gmail.com  None
# 6       NaN       NaN                      NaN   NaN

# %%
df.dropna(axis='index',how='all',subset=['email'])
# Out:
#       first     last                    email   age
# 0    Ankita  Pradhan  ankitapradgan@gmail.com    33
# 1    Akshat    Bajaj    akshatbajaj@gmail.com    35
# 2  Mohammed    Saleh      mohdsaleg@gmail.com    40
# 5      None      NaN      anonymous@gmail.com  None

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('MISSING')
# Out:
#       first      last                    email      age
# 0    Ankita   Pradhan  ankitapradgan@gmail.com       33
# 1    Akshat     Bajaj    akshatbajaj@gmail.com       35
# 2  Mohammed     Saleh      mohdsaleg@gmail.com       40
# 3    Pranav  Muketjee                  MISSING       63
# 4   MISSING   MISSING                  MISSING  MISSING
# 5   MISSING   MISSING      anonymous@gmail.com  MISSING
# 6   MISSING   MISSING                  MISSING  MISSING

# %%
df.fillna(0)
# Out:
#       first      last                    email age
# 0    Ankita   Pradhan  ankitapradgan@gmail.com  33
# 1    Akshat     Bajaj    akshatbajaj@gmail.com  35
# 2  Mohammed     Saleh      mohdsaleg@gmail.com  40
# 3    Pranav  Muketjee                        0  63
# 4         0         0                        0   0
# 5         0         0      anonymous@gmail.com   0
# 6         0         0                        0   0

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
#this works if the values are NAN or None
df['age']=df['age'].astype(float)

# %%
df['age'].mean()
# Out:
# 42.75

# %%
df['age'].median()
# Out:
# 37.5

# %%
df['age'].unique()
# Out:
# array([33., 35., 40., 63., nan])
